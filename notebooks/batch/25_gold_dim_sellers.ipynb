# %% [markdown]
# # Gold: dim_sellers

# %% [markdown]
# ## Import Helper Functions

# %%
from src.pipeline.batch.common.config_loader import load_config
from src.pipeline.batch.common.spark_sql_magic import sql
from src.pipeline.batch.gold.helper import get_changed_seller_ids
from src.pipeline.batch.gold.dims.sellers import build_dim_sellers_scd2, build_incremental_dim_sellers, validate_scd2_sellers
from src.pipeline.batch.monitoring.dq_metrics import write_dq_metrics
from src.pipeline.batch.common.watermark import  get_last_commit_ts, get_effective_watermark
from src.pipeline.batch.common.writers import overwrite_table, replace_by_key
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
SILVER_NAMESPACE = cfg["general"]["namespaces"]["silver"]
GOLD_NAMESPACE = cfg["general"]["namespaces"]["gold"]

cfg_sellers = cfg["gold"]["dim_sellers_scd2"]
SOURCE_TABLE = cfg_sellers["source_table"]
TARGET_TABLE = cfg_sellers["target_table"]
GEO_TABLE = cfg_sellers["geo_table"]
BUFFER_HOURS = cfg_sellers["buffer_hours"]
KEY_COLUMNS = cfg_sellers["key_columns"]

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["gold_sellers"])
        .getOrCreate()
)

# %% [markdown]
# ## Run Pipeline

# %%
def run_dim_sellers_pipeline(spark):
    print("[START] dim_sellers pipeline")

    last_commit_ts = get_last_commit_ts(spark, TARGET_TABLE)
    print(f"[INFO] last_commit_ts = {last_commit_ts}")

    if last_commit_ts is None:
        print("[INFO] first run → full rebuild")
        df = build_dim_sellers_scd2(spark, SOURCE_TABLE, GEO_TABLE)
        metrics = validate_scd2_sellers(df)
        write_dq_metrics(df, metrics, "dim_sellers_scd2", GOLD_NAMESPACE, "monitoring.dq_metrics")
        overwrite_table(df, TARGET_TABLE)
        print("[END] full rebuild complete")
        return

    effective_ts = get_effective_watermark(last_commit_ts, BUFFER_HOURS)
    changed_seller_ids = get_changed_seller_ids(spark, effective_ts)

    if changed_seller_ids.isEmpty():
        print("[INFO] no changes detected → skip")
        return
    print("[INFO] changes detected → incremental run")

    df = build_incremental_dim_sellers(spark, SOURCE_TABLE, GEO_TABLE, changed_seller_ids)
    metrics = validate_scd2_sellers(df)
    write_dq_metrics(df, metrics, "dim_sellers_scd2", GOLD_NAMESPACE, "monitoring.dq_metrics")
    replace_by_key(spark, df, TARGET_TABLE, KEY_COLUMNS)
    print("[END] incremental update complete")

# %%
# if __name__ == "__main__":
#     from pyspark.sql import SparkSession

#     spark = SparkSession.builder.getOrCreate()
run_dim_sellers_pipeline(spark)
# Out:
# [START] dim_sellers pipeline
# [INFO] last_commit_ts = None
# [INFO] first run → full rebuild
# [END] full rebuild complete

# %% [markdown]
# ## Sanity Check

# %%
# %%sql
# SHOW TABLES IN polaris.gold;
# Out:
# +---------+------------------+-----------+
# |namespace|tableName         |isTemporary|
# +---------+------------------+-----------+
# |gold     |dim_customers_scd2|false      |
# |gold     |dim_sellers_scd2  |false      |
# +---------+------------------+-----------+

# %%
# %%sql
# SELECT * FROM polaris.gold.dim_sellers_scd2
# LIMIT 10
# Out:
# +--------------------------------+----------------------+--------------+------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+------------+----------+----------------------------------------------------------------+
# |seller_id                       |seller_zip_code_prefix|seller_city   |seller_state|geolocation_lat    |geolocation_lng    |cdc_ts                 |spark_ingest_ts        |effective_from         |effective_to|is_current|seller_sk                                                       |
# +--------------------------------+----------------------+--------------+------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+------------+----------+----------------------------------------------------------------+
# |0015a82c2db000af6aaaf3ae2ecb0532|09080                 |Santo Andre   |SP          |-23.640443596560726|-46.541742273007685|2026-04-15 01:54:57.387|2026-04-15 02:52:31.474|2026-04-15 01:54:57.387|NULL        |true      |14208c39e743d98b56030f14325faef75bae5cd1a0a0f4831ecd7e02c5bf6155|
# |001cca7ae9ae17fb1caed9dfb1094831|29156                 |Cariacica     |ES          |-20.27851289140612 |-40.411675223412075|2026-04-15 01:54:57.309|2026-04-15 02:52:31.474|2026-04-15 01:54:57.309|NULL        |true      |9fab9765536476d0bbdaff09f7db01664a8086576343e3b70599ad32db09d550|
# |001e6ad469a905060d959994f1b41e4f|24754                 |Sao Goncalo   |RJ          |-22.872354587681087|-43.027432812835386|2026-04-15 01:54:57.31 |2026-04-15 02:52:31.474|2026-04-15 01:54:57.31 |NULL        |true      |3b2b1a197fad942705c4dc52a569f0f1a97ef3bae0b11deaa155cb2f52cdebb1|
