# %% [markdown]
# # Gold: fact_orders

# %% [markdown]
# ## Import Helper Functions

# %%
from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# from src.config_loader import load_config
# from src.spark_sql_magic import sql
# from src.gold.facts.orders import build_fact_orders, build_fact_orders_incremental, get_changed_customer_ids, get_changed_order_ids, validate_fact_orders
# from src.watermark import  get_last_commit_ts, get_effective_watermark, get_changed_keys
# from src.writer import overwrite_table, replace_by_key
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
SILVER_NAMESPACE = cfg["general"]["namespaces"]["silver"]
GOLD_NAMESPACE = cfg["general"]["namespaces"]["gold"]

cfg_orders= cfg["gold"]["fact_orders"]
TARGET_TABLE = cfg_orders["target_table"]
SOURCE_TABLE = cfg_orders["source_table"]
CUSTOMERS_TABLE = cfg_orders["customers_table"]
DATE_TABLE = cfg_orders["date_table"]
BUFFER_HOURS = cfg_orders["buffer_hours"]
KEY_COLUMN = cfg_orders["key_column"]

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["gold_orders"])
        .getOrCreate()
)

# %% [markdown]
# ## Run Pipeline

# %%
def run_fact_orders_pipeline(spark):
    print("[START] fact_orders pipeline")

    last_commit_ts = get_last_commit_ts(spark, TARGET_TABLE)
    print(f"[INFO] last_commit_ts = {last_commit_ts}")

    if last_commit_ts is None:
        print("[INFO] first run → full rebuild")
        df = build_fact_orders(spark, SOURCE_TABLE, CUSTOMERS_TABLE, DATE_TABLE)
        validate_fact_orders(df)
        overwrite_table(df, TARGET_TABLE)
        print("[END] full rebuild complete")
        return
    
    effective_ts = get_effective_watermark(last_commit_ts, BUFFER_HOURS)
    changed_customer_ids = get_changed_customer_ids(spark, effective_ts)
    changed_order_ids = get_changed_order_ids(spark, effective_ts)

    if changed_customer_ids.limit(1).count() == 0 and changed_order_ids.limit(1).count() == 0:
        print("[INFO] no changes detected → skip")
        return

    print("[INFO] changes detected → incremental run")
    df = build_fact_orders_incremental(
        spark,
        SOURCE_TABLE,
        CUSTOMERS_TABLE,
        DATE_TABLE,
        changed_customer_ids,
        changed_order_ids,
    )
    validate_fact_orders(df)
    replace_by_key(spark, df, TARGET_TABLE, KEY_COLUMN)
    print("[END] incremental update complete")

# %%
# if __name__ == "__main__":
#     from pyspark.sql import SparkSession

#     spark = SparkSession.builder.getOrCreate()
run_fact_orders_pipeline(spark)
# Out:
# [START] fact_orders pipeline
# [INFO] last_commit_ts = None
# [INFO] first run → full rebuild
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       1 # if __name__ == "__main__":
#       2 #     from pyspark.sql import SparkSession
#       3
#       4 #     spark = SparkSession.builder.getOrCreate()
# ----> 5 run_fact_orders_pipeline(spark)
#
# Cell In[4], line 10, in run_fact_orders_pipeline(spark)
#       8 print("[INFO] first run → full rebuild")
#       9 df = build_fact_orders(spark, SOURCE_TABLE, CUSTOMERS_TABLE, DATE_TABLE)
# ---> 10 validate_fact_orders(df)
#      11 overwrite_table(df, TARGET_TABLE)
#      12 print("[END] full rebuild complete")
#
# File /home/iceberg/notebooks/src/gold/facts/orders.py:108, in validate_fact_orders(df)
#     106 nulls = df.filter(F.col("customer_sk").isNull())
#     107 if nulls.limit(1).count() > 0:
# --> 108     raise ValueError("Null customer_sk found in fact_orders")
#     110 # Valid date SKs
#     111 for c in ["order_purchase_date_sk", "order_delivered_customer_date_sk"]:
#
# ValueError: Null customer_sk found in fact_orders

# %% [markdown]
# ## Sanity Check

# %%
# %%sql
# SHOW TABLES IN polaris.gold;

# %%
# %%sql
# SELECT * FROM polaris.gold.fact_orders
# LIMIT 10

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
