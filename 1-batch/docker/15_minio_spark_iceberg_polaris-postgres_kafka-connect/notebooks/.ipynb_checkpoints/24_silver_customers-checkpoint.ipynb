# %% [markdown]
# # Silver Customers

# %% [markdown]
# ## Import Helper Functions

# %%
from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
BRONZE_NAMESPACE = cfg["general"]["namespaces"]["bronze"]
SILVER_NAMESPACE = cfg["general"]["namespaces"]["silver"]
MONITORING_NAMESPACE = cfg["general"]["namespaces"]["monitoring"]
TOPIC_SUFFIX = cfg["kafka"]["topic_suffix"]

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["silver"])
        .getOrCreate()
)

# %% [markdown]
# ## Read from Bronze (Incremental)

# %%
def read_bronze_incremental(tablename: str) -> DataFrame:

    bronze_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{tablename}"
    silver_table = f"{CATALOG}.{SILVER_NAMESPACE}.{tablename}"

    if not spark.catalog.tableExists(silver_table):
        return spark.table(bronze_table)

    return spark.sql(f"""
        SELECT *
        FROM {bronze_table}
        WHERE spark_ingest_ts >
        COALESCE(
            (SELECT MAX(spark_ingest_ts) FROM {silver_table}),
            TIMESTAMP '1970-01-01'
        )
    """)

# %% [markdown]
# ## Common Function 1: Normalize CDC

# %%
def normalize_cdc(df: DataFrame) -> DataFrame:
    """
    1 normalize CDC operation
    2 rename CDC timestamp
    3 convert CDC timestamp to real timestamp
    """
    return (
        df
        .withColumn("cdc_op",
            F.when(F.col("__op") == "r", F.lit("c"))
             .otherwise(F.col("__op"))
        )       
        .withColumnRenamed("__ts_ms", "cdc_ts_ms")
        .withColumn("cdc_ts", F.to_timestamp(F.col("cdc_ts_ms") / 1000))
        .withColumn("ds", F.to_date("cdc_ts"))   # easier to query downstream
    )

# %% [markdown]
# ## Common Function 2: Normalize Decimal Struct

# %%
from pyspark.sql.types import StructType, BinaryType, IntegerType, DecimalType

def normalize_decimal_structs(df: DataFrame) -> DataFrame:
    """
    Convert Avro-decoded decimal structs to numeric types.
    Looks for columns with schema: StructType(scale:int, value:binary)

    df (DataFrame)
     └ df.schema  → StructType
           └ fields  → list of StructField
                 └ field.name       → column name
                 └ field.dataType  → column type (IntegerType, StringType, StructType, etc)
                       └ if StructType: field.dataType.fields → inner list of StructField    
    """
    # Step 1: collect all decimal struct columns
    decimal_cols = []

    for field in df.schema.fields:
        if not isinstance(field.dataType, StructType):
            continue  # skip non-struct columns

        # get inner field names and types
        inner_fields = {f.name: f.dataType for f in field.dataType.fields}

        # detect decimal struct pattern
        if inner_fields.get("scale") == IntegerType() and inner_fields.get("value") == BinaryType():
            decimal_cols.append(field.name)

    # Step 2: apply normalization for each detected column
    for col_name in decimal_cols:
        df = df.withColumn(
                col_name,
                (F.conv(F.hex(F.col(f"{col_name}.value")), 16, 10).cast(DecimalType(38,0)) /
                F.pow(10, F.col(f"{col_name}.scale")))
                .cast(DecimalType(18,6))
            )

    return df

# %% [markdown]
# ## Common Function 3: Drop Kafka Metadata

# %%
def drop_kafka_metadata(df: DataFrame) -> DataFrame:
    kafka_metadata_cols = [col for col in df.columns if col.startswith("kafka_")]
    if kafka_metadata_cols:
        return df.drop(*kafka_metadata_cols)
    return df

# %% [markdown]
# ## Function: Apply Common Transform

# %%
def apply_common_transform(df: DataFrame) -> DataFrame:
    df = normalize_cdc(df)
    df = normalize_decimal_structs(df) 
    df = drop_kafka_metadata(df)
    return df

# %% [markdown]
# ## Function: Apply Table Specific Transform

# %%
from src.silver.transform import TABLE_TRANSFORMS

def apply_table_specific_transform(df: DataFrame, tablename: str) -> DataFrame:
    transform_fn = TABLE_TRANSFORMS.get(tablename)
    if transform_fn is None:
        raise ValueError(
            f"No table-specific transform registered for '{tablename}'. "
            f"Available: {sorted(TABLE_TRANSFORMS)}"
        )
    return transform_fn(df)

# %% [markdown]
# ## Function: Apply Schema Drift

# %%
from pyspark.sql.utils import AnalysisException

def apply_schema_drift(silver_ready_df, silver_table_name):
    """
    Detects table existence, handles additive schema evolution,
    and prevents destructive schema changes.
    """
    # ---- Detect table existence ----
    try:
        silver_existing_df = spark.table(silver_table_name)
    except AnalysisException:
        return False   # table does not exist
    
    # ---- Drift Detection ----
    incoming_cols = set(silver_ready_df.columns)
    existing_cols = set(silver_existing_df.columns)
    
    new_cols = incoming_cols - existing_cols
    missing_cols = existing_cols - incoming_cols
    
    if missing_cols:
        raise Exception(f"Destructive schema change detected: {missing_cols}")
    
    # ---- Additive evolution ----
    for col in new_cols:
        dtype = silver_ready_df.schema[col].dataType.simpleString()
        spark.sql(f"""
            ALTER TABLE {silver_table_name} 
            ADD COLUMN {col} {dtype}
        """)

    return True

# %% [markdown]
# ## DDL: Create Table DQ Metrics

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS monitoring.dq_metrics (
#     pipeline_stage STRING,
#     source_table STRING,
#     metric_name STRING,
#     metric_value BIGINT,
#     timestamp TIMESTAMP
# )
# USING ICEBERG
# PARTITIONED BY (pipeline_stage, source_table)

# %% [markdown]
# ## Function: Collect Table DQ Metrics

# %%
from src.silver.dq import TABLE_DQ_METRICS
from src.silver.dq.common_dq import collect_common_dq_metrics

def collect_table_dq_metrics(df, table_name: str):
    collect_common_dq_metrics(df, table_name)

    table_dq_fn = TABLE_DQ_METRICS.get(table_name)
    if table_dq_fn is None:
        raise ValueError(
            f"No table-specific DQ metrics function registered for '{table_name}'. "
            f"Available: {sorted(TABLE_DQ_METRICS)}"
        )

    table_dq_fn(df, table_name)

    return df

# %% [markdown]
# ## Call logging/audit function

# %% [markdown]
# ## Append only model (Functional DE)
# I know many would question this code below so I included the reference.
# ### Reference:
# - [The Data Warehouse Setup No One Taught You](https://blog.dataexpert.io/p/the-data-warehouse-setup-no-one-taught)
# - [Functional Data Engineering — a modern paradigm for batch data processing](https://maximebeauchemin.medium.com/functional-data-engineering-a-modern-paradigm-for-batch-data-processing-2327ec32c42a)

# %%
def run_silver_pipeline(table_name):
    df = read_bronze_incremental(table_name)
    df = apply_common_transform(df)
    df = apply_table_specific_transform(df, table_name)
    silver_table_name = f"{CATALOG}.{SILVER_NAMESPACE}.{table_name}"
    table_exists = apply_schema_drift(df, silver_table_name)
    df = collect_table_dq_metrics(df, table_name)
    df = df.repartition("ds")                                               # when table becomes bigger, need to repartition more columns
    writer = (
        df.writeTo(silver_table_name)                                       # DataFrameWriterV2
        .using("iceberg")
        .tableProperty("format-version", "3")
        .tableProperty("write.format.default", "parquet")
        .tableProperty("write.parquet.compression-codec", "zstd")
        .tableProperty("write.target-file-size-bytes", "134217728")         # <- this depends on daily data size
        .partitionedBy("ds")                                                # can also F.partitioning.days("cdc_ts")
    )
    
    if table_exists:
        writer.append()
    else:
        writer.create()

    # Call logging/audit function here

# %%
for table_name in TABLE_TRANSFORMS:                                        # sequential job now, if parallel need to add orchestrator like airflow
    print(f"Running silver transform for: {table_name}")
    run_silver_pipeline(table_name)
# Out:
# Running silver transform for: customers
# Running silver transform for: order_items
# Running silver transform for: order_payments
# Running silver transform for: order_reviews
# Running silver transform for: orders
# Running silver transform for: products
# Running silver transform for: sellers

# %% [markdown]
# ## Sanity Check

# %%
w = W.partitionBy("pipeline_stage", "source_table", "metric_name").orderBy(F.col("timestamp").desc())

dq_df = (
        spark.table(f"{CATALOG}.{MONITORING_NAMESPACE}.dq_metrics")
        .withColumn("row_num", F.row_number().over(w))
        .filter(F.col("row_num") == 1)
        .drop("row_num")
    )

for table_name in TABLE_TRANSFORMS:
    df = dq_df.filter(F.col("source_table") == table_name)
    df.show(n=50)
# Out:
# +--------------+------------+--------------------+------------+--------------------+
# |pipeline_stage|source_table|         metric_name|metric_value|           timestamp|
# +--------------+------------+--------------------+------------+--------------------+
# |        silver|   customers|          bad_cdc_op|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|     duplicate_count|           0|2026-03-16 05:53:...|
# |        silver|   customers|       future_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|   future_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|   future_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|   customers| invalid_customer_id|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|invalid_customer_...|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|invalid_customer_...|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|       null_batch_id|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|         null_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|     null_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|    null_customer_id|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|null_customer_uni...|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|             null_ds|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|null_spark_ingest_ts|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|     null_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|          old_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|      old_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|      old_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|   customers|          total_rows|           0|2026-03-16 05:53:...|
# +--------------+------------+--------------------+------------+--------------------+
#
# +--------------+------------+--------------------+------------+--------------------+
# |pipeline_stage|source_table|         metric_name|metric_value|           timestamp|
# +--------------+------------+--------------------+------------+--------------------+
# |        silver| order_items|          bad_cdc_op|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|     duplicate_count|           0|2026-03-16 05:53:...|
# |        silver| order_items|       future_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|   future_created_at|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|future_shipping_l...|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|   future_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|    invalid_order_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|       invalid_price|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|  invalid_product_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|   invalid_seller_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|negative_freight_...|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|negative_order_it...|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|       null_batch_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|         null_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|     null_created_at|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|             null_ds|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|       null_order_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|  null_order_item_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|     null_product_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|      null_seller_id|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|null_shipping_lim...|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|null_spark_ingest_ts|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|     null_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|          old_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|      old_created_at|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|old_shipping_limi...|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|      old_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver| order_items|          total_rows|           0|2026-03-16 05:53:...|
# +--------------+------------+--------------------+------------+--------------------+
#
# +--------------+--------------+--------------------+------------+--------------------+
# |pipeline_stage|  source_table|         metric_name|metric_value|           timestamp|
# +--------------+--------------+--------------------+------------+--------------------+
# |        silver|order_payments|          bad_cdc_op|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|     duplicate_count|           0|2026-03-16 05:53:...|
# |        silver|order_payments|       future_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|   future_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|   future_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|    invalid_order_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|invalid_payment_i...|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|invalid_payment_s...|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|invalid_payment_type|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|negative_payment_...|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|       null_batch_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|         null_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|     null_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|             null_ds|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|       null_order_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|  null_payment_value|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|null_spark_ingest_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|     null_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|          old_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|      old_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|      old_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_payments|          total_rows|           0|2026-03-16 05:53:...|
# +--------------+--------------+--------------------+------------+--------------------+
#
# +--------------+-------------+--------------------+------------+--------------------+
# |pipeline_stage| source_table|         metric_name|metric_value|           timestamp|
# +--------------+-------------+--------------------+------------+--------------------+
# |        silver|order_reviews|          bad_cdc_op|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|     duplicate_count|           0|2026-03-16 05:53:...|
# |        silver|order_reviews|       future_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|   future_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|future_review_ans...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|future_review_cre...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|   future_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|    invalid_order_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|   invalid_review_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|invalid_review_score|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|missing_review_co...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|missing_review_co...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|       null_batch_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|         null_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|     null_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|             null_ds|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|       null_order_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|null_review_answe...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|null_review_creat...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|      null_review_id|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|   null_review_score|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|null_spark_ingest_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|     null_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|          old_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|      old_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|old_review_answer...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|old_review_creati...|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|      old_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|order_reviews|          total_rows|           0|2026-03-16 05:53:...|
# +--------------+-------------+--------------------+------------+--------------------+
#
# +--------------+------------+--------------------+------------+--------------------+
# |pipeline_stage|source_table|         metric_name|metric_value|           timestamp|
# +--------------+------------+--------------------+------------+--------------------+
# |        silver|      orders|          bad_cdc_op|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|     duplicate_count|           0|2026-03-16 05:53:...|
# |        silver|      orders|       future_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|   future_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|   future_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|      orders| invalid_customer_id|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|invalid_order_app...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|invalid_order_del...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|invalid_order_del...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|invalid_order_est...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|    invalid_order_id|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|invalid_order_pur...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|invalid_order_status|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|       null_batch_id|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|         null_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|     null_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|    null_customer_id|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|             null_ds|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|null_order_estima...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|       null_order_id|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|null_order_purcha...|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|null_spark_ingest_ts|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|     null_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|          old_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|      old_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|      old_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|      orders|          total_rows|           0|2026-03-16 05:53:...|
# +--------------+------------+--------------------+------------+--------------------+
#
# +--------------+------------+--------------------+------------+--------------------+
# |pipeline_stage|source_table|         metric_name|metric_value|           timestamp|
# +--------------+------------+--------------------+------------+--------------------+
# |        silver|    products|          bad_cdc_op|        NULL|2026-03-16 05:53:...|
# |        silver|    products|     duplicate_count|           0|2026-03-16 05:53:...|
# |        silver|    products|       future_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|    products|   future_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|    products|   future_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|    products|invalid_product_h...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|  invalid_product_id|        NULL|2026-03-16 05:53:...|
# |        silver|    products|invalid_product_l...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|invalid_product_v...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|invalid_product_w...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|invalid_product_w...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|missing_product_c...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|negative_product_...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|negative_product_...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|negative_product_...|        NULL|2026-03-16 05:53:...|
# |        silver|    products|       null_batch_id|        NULL|2026-03-16 05:53:...|
# |        silver|    products|         null_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|    products|     null_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|    products|             null_ds|        NULL|2026-03-16 05:53:...|
# |        silver|    products|     null_product_id|        NULL|2026-03-16 05:53:...|
# |        silver|    products|null_spark_ingest_ts|        NULL|2026-03-16 05:53:...|
# |        silver|    products|     null_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|    products|          old_cdc_ts|        NULL|2026-03-16 05:53:...|
# |        silver|    products|      old_created_at|        NULL|2026-03-16 05:53:...|
# |        silver|    products|      old_updated_at|        NULL|2026-03-16 05:53:...|
# |        silver|    products|          total_rows|           0|2026-03-16 05:53:...|
# +--------------+------------+--------------------+------------+--------------------+
#
# +--------------+------------+--------------------+------------+--------------------+
# |pipeline_stage|source_table|         metric_name|metric_value|           timestamp|
# +--------------+------------+--------------------+------------+--------------------+
# |        silver|     sellers|          bad_cdc_op|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|     duplicate_count|           0|2026-03-16 05:54:...|
# |        silver|     sellers|       future_cdc_ts|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|   future_created_at|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|   future_updated_at|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|   invalid_seller_id|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|invalid_seller_zi...|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|       null_batch_id|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|         null_cdc_ts|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|     null_created_at|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|             null_ds|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|      null_seller_id|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|null_spark_ingest_ts|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|     null_updated_at|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|          old_cdc_ts|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|      old_created_at|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|      old_updated_at|        NULL|2026-03-16 05:54:...|
# |        silver|     sellers|          total_rows|           0|2026-03-16 05:54:...|
# +--------------+------------+--------------------+------------+--------------------+

# %%
# %%sql
# SELECT COUNT(*) FROM polaris.silver.customers
# Out:
# +--------+
# |count(1)|
# +--------+
# |99441   |
# +--------+

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
