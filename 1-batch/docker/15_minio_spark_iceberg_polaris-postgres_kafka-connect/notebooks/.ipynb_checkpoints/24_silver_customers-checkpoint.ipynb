# %% [markdown]
# # Silver Customers

# %% [markdown]
# ## Import Helper Functions

# %%
from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
BRONZE_NAMESPACE = cfg["general"]["namespaces"]["bronze"]
SILVER_NAMESPACE = cfg["general"]["namespaces"]["silver"]
MONITORING_NAMESPACE = cfg["general"]["namespaces"]["monitoring"]
TOPIC_SUFFIX = cfg["kafka"]["topic_suffix"]

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["silver"])
        .getOrCreate()
)

# %% [markdown]
# ## Read from Bronze

# %%
def read_bronze_table(tablename: str) -> DataFrame:
    BRONZE_TABLE = f"{CATALOG}.{BRONZE_NAMESPACE}.{tablename}"
    bronze_df = spark.read.format("iceberg").table(BRONZE_TABLE) 
    return bronze_df

# %% [markdown]
# ## Common Function 1: Normalize CDC

# %%
def normalize_cdc(df: DataFrame) -> DataFrame:
    """
    1 normalize CDC operation
    2 rename CDC timestamp
    3 convert CDC timestamp to real timestamp
    """
    return (
        df
        .withColumn("cdc_op",
            F.when(F.col("__op") == "r", F.lit("c"))
             .otherwise(F.col("__op"))
        )       
        .withColumnRenamed("__ts_ms", "cdc_ts_ms")
        .withColumn("cdc_ts", F.to_timestamp(F.col("cdc_ts_ms") / 1000))
        .withColumn("ds", F.to_date("cdc_ts"))   # easier to query downstream
    )

# %% [markdown]
# ## Common Function 2: Normalize Decimal Struct

# %%
from pyspark.sql.types import StructType, BinaryType, IntegerType, DecimalType

def normalize_decimal_structs(df: DataFrame) -> DataFrame:
    """
    Convert Avro-decoded decimal structs to numeric types.
    Looks for columns with schema: StructType(scale:int, value:binary)

    df (DataFrame)
     └ df.schema  → StructType
           └ fields  → list of StructField
                 └ field.name       → column name
                 └ field.dataType  → column type (IntegerType, StringType, StructType, etc)
                       └ if StructType: field.dataType.fields → inner list of StructField    
    """
    # Step 1: collect all decimal struct columns
    decimal_cols = []

    for field in df.schema.fields:
        if not isinstance(field.dataType, StructType):
            continue  # skip non-struct columns

        # get inner field names and types
        inner_fields = {f.name: f.dataType for f in field.dataType.fields}

        # detect decimal struct pattern
        if inner_fields.get("scale") == IntegerType() and inner_fields.get("value") == BinaryType():
            decimal_cols.append(field.name)

    # Step 2: apply normalization for each detected column
    for col_name in decimal_cols:
        df = df.withColumn(
                col_name,
                (F.conv(F.hex(F.col(f"{col_name}.value")), 16, 10).cast(DecimalType(38,0)) /
                F.pow(10, F.col(f"{col_name}.scale")))
                .cast(DecimalType(18,6))
            )

    return df

# %% [markdown]
# ## Common Function 3: Drop Kafka Metadata

# %%
def drop_kafka_metadata(df: DataFrame) -> DataFrame:
    kafka_metadata_cols = [col for col in df.columns if col.startswith("kafka_")]
    if kafka_metadata_cols:
        return df.drop(*kafka_metadata_cols)
    return df

# %% [markdown]
# ## Function: Apply Common Transform

# %%
def apply_common_transform(df: DataFrame) -> DataFrame:
    df = normalize_cdc(df)
    df = normalize_decimal_structs(df) 
    df = drop_kafka_metadata(df)
    return df

# %% [markdown]
# ## Function: Apply Table Specific Transform

# %%
from src.silver.transform import TABLE_TRANSFORMS

def apply_table_specific_transform(df: DataFrame, tablename: str) -> DataFrame:
    transform_fn = TABLE_TRANSFORMS.get(tablename)
    if transform_fn is None:
        raise ValueError(
            f"No table-specific transform registered for '{tablename}'. "
            f"Available: {sorted(TABLE_TRANSFORMS)}"
        )
    return transform_fn(df)

# %% [markdown]
# ## Function: Apply Schema Drift

# %%
from pyspark.sql.utils import AnalysisException

def apply_schema_drift(silver_ready_df, silver_table_name):
    """
    Detects table existence, handles additive schema evolution,
    and prevents destructive schema changes.
    """
    # ---- Detect table existence ----
    try:
        silver_existing_df = spark.table(silver_table_name)
    except AnalysisException:
        return False   # table does not exist
    
    # ---- Drift Detection ----
    incoming_cols = set(silver_ready_df.columns)
    existing_cols = set(silver_existing_df.columns)
    
    new_cols = incoming_cols - existing_cols
    missing_cols = existing_cols - incoming_cols
    
    if missing_cols:
        raise Exception(f"Destructive schema change detected: {missing_cols}")
    
    # ---- Additive evolution ----
    for col in new_cols:
        dtype = silver_ready_df.schema[col].dataType.simpleString()
        spark.sql(f"""
            ALTER TABLE {silver_table_name} 
            ADD COLUMN {col} {dtype}
        """)

    return True

# %% [markdown]
# ## Function: Collect Table DQ Metrics

# %%
from src.silver.dq import TABLE_DQ_METRICS
from src.silver.dq.common_dq import collect_common_dq_metrics

def collect_table_dq_metrics(df, table_name: str):
    collect_common_dq_metrics(df, table_name)

    table_dq_fn = TABLE_DQ_METRICS.get(table_name)
    if table_dq_fn is None:
        raise ValueError(
            f"No table-specific DQ metrics function registered for '{table_name}'. "
            f"Available: {sorted(TABLE_DQ_METRICS)}"
        )

    table_dq_fn(df, table_name)

    return df

# %% [markdown]
# ## Call logging/audit function

# %% [markdown]
# ## Append only model (Functional DE)
# I know many would question this code below so I included the reference.
# ### Reference:
# - [The Data Warehouse Setup No One Taught You](https://blog.dataexpert.io/p/the-data-warehouse-setup-no-one-taught)
# - [Functional Data Engineering — a modern paradigm for batch data processing](https://maximebeauchemin.medium.com/functional-data-engineering-a-modern-paradigm-for-batch-data-processing-2327ec32c42a)

# %%
for table_name in TABLE_TRANSFORMS:
    print(f"Running silver transform for: {table_name}")
    df = read_bronze_table(table_name)
    df = apply_common_transform(df)
    df = apply_table_specific_transform(df, table_name)
    silver_table_name = f"{CATALOG}.{SILVER_NAMESPACE}.{table_name}"
    table_exists = apply_schema_drift(df, silver_table_name)
    df = collect_table_dq_metrics(df, table_name)
    df = df.repartition("ds")                   # when table becomes bigger, need to repartition more columns
    writer = (
        df.writeTo(silver_table_name)
        .using("iceberg")
        .tableProperty("format-version", "3")
        .tableProperty("write.format.default", "parquet")
        .tableProperty("write.parquet.compression-codec", "zstd")
        .tableProperty("write.target-file-size-bytes", "134217728")         # <- this depends on daily data size
        .partitionedBy(F.partitioning.days("ds"))
    )
    
    if table_exists:
        writer.append()
    else:
        writer.create()

    # Call logging/audit function here
# Out:
# Running silver transform for: customers
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[12], line 8
#       6 silver_table_name = f"{CATALOG}.{SILVER_NAMESPACE}.{table_name}"
#       7 table_exists = apply_schema_drift(df, silver_table_name)
# ----> 8 df = collect_table_dq_metrics(df, table_name)
#       9 df = df.repartition("ds")                   # when table becomes bigger, need to repartition more columns
#      10 writer = (
#      11     df.writeTo(silver_table_name)
#      12     .using("iceberg")
#    (...)
#      17     .partitionedBy(F.partitioning.days("ds"))
#      18 )
#
# Cell In[11], line 5, in collect_table_dq_metrics(df, table_name)
#       4 def collect_table_dq_metrics(df, table_name: str):
# ----> 5     collect_common_dq_metrics(df, table_name)
#       7     table_dq_fn = TABLE_DQ_METRICS.get(table_name)
#       8     if table_dq_fn is None:
#
# File /home/iceberg/notebooks/src/silver/dq/common_dq.py:35, in collect_common_dq_metrics(df, table_name)
#      27 metrics_df = df.agg(*metrics)
#      29 metrics_df = (
#      30     metrics_df.withColumn("pipeline_stage", F.lit("silver"))
#      31     .withColumn("source_table", F.lit(table_name))
#      32     .withColumn("timestamp", F.current_timestamp())
#      33 )
# ---> 35 metrics_df.writeTo("monitoring.dq_metrics").append()
#      37 return df
#
# File /usr/local/lib/python3.10/dist-packages/pyspark/sql/readwriter.py:2489, in DataFrameWriterV2.append(self)
#    2483 def append(self) -> None:
#    2484     """
#    2485     Append the contents of the data frame to the output table.
#    2486
#    2487     .. versionadded: 3.1.0
#    2488     """
# -> 2489     self._jwriter.append()
#
# File /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/lib/python3.10/dist-packages/pyspark/errors/exceptions/captured.py:288, in capture_sql_exception.<locals>.deco(*a, **kw)
#     284 converted = convert_exception(e.java_exception)
#     285 if not isinstance(converted, UnknownException):
#     286     # Hide where the exception came from that shows a non-Pythonic
#     287     # JVM exception message.
# --> 288     raise converted from None
#     289 else:
#     290     raise
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `monitoring`.`dq_metrics` cannot be found. Verify the spelling and correctness of the schema and catalog.
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS. SQLSTATE: 42P01;
# 'AppendData 'UnresolvedRelation [monitoring, dq_metrics], [__required_write_privileges__=INSERT], false, true
# +- Project [total_rows#58L, bad_cdc_op#59L, null_cdc_ts#60L, old_cdc_ts#61L, null_created_at#62L, old_created_at#63L, null_updated_at#64L, old_updated_at#65L, future_cdc_ts#66L, future_created_at#67L, future_updated_at#68L, null_ds#69L, null_spark_ingest_ts#70L, null_batch_id#71L, pipeline_stage#100, source_table#101, current_timestamp() AS timestamp#103]
#    +- Project [total_rows#58L, bad_cdc_op#59L, null_cdc_ts#60L, old_cdc_ts#61L, null_created_at#62L, old_created_at#63L, null_updated_at#64L, old_updated_at#65L, future_cdc_ts#66L, future_created_at#67L, future_updated_at#68L, null_ds#69L, null_spark_ingest_ts#70L, null_batch_id#71L, pipeline_stage#100, customers AS source_table#101]
#       +- Project [total_rows#58L, bad_cdc_op#59L, null_cdc_ts#60L, old_cdc_ts#61L, null_created_at#62L, old_created_at#63L, null_updated_at#64L, old_updated_at#65L, future_cdc_ts#66L, future_created_at#67L, future_updated_at#68L, null_ds#69L, null_spark_ingest_ts#70L, null_batch_id#71L, silver AS pipeline_stage#100]
#          +- Aggregate [count(1) AS total_rows#58L, sum(cast(NOT cdc_op#36 IN (c,u,d) as int)) AS bad_cdc_op#59L, sum(cast(isnull(cdc_ts#37) as int)) AS null_cdc_ts#60L, sum(cast((cdc_ts#37 < cast(2000-01-01 00:00:00 as timestamp)) as int)) AS old_cdc_ts#61L, sum(cast(isnull(created_at#54) as int)) AS null_created_at#62L, sum(cast((created_at#54 < cast(2000-01-01 00:00:00 as timestamp)) as int)) AS old_created_at#63L, sum(cast(isnull(updated_at#55) as int)) AS null_updated_at#64L, sum(cast((updated_at#55 < cast(2000-01-01 00:00:00 as timestamp)) as int)) AS old_updated_at#65L, sum(cast((cdc_ts#37 > current_timestamp()) as int)) AS future_cdc_ts#66L, sum(cast((created_at#54 > cast(current_timestamp() + INTERVAL '1' DAY as timestamp)) as int)) AS future_created_at#67L, sum(cast((updated_at#55 > cast(current_timestamp() + INTERVAL '1' DAY as timestamp)) as int)) AS future_updated_at#68L, sum(cast(isnull(ds#38) as int)) AS null_ds#69L, sum(cast(isnull(spark_ingest_ts#35) as int)) AS null_spark_ingest_ts#70L, sum(cast(isnull(batch_id#34) as int)) AS null_batch_id#71L]
#             +- Deduplicate [customer_id#40, cdc_ts#37]
#                +- Filter RLIKE(customer_unique_id#42, ^[a-fA-F0-9]{32}$)
#                   +- Filter RLIKE(customer_id#40, ^[a-fA-F0-9]{32}$)
#                      +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#49, customer_city#56, translate(customer_state#53, áàâãäéèêëíìîïóòôõöúùûüçñÁÀÂÃÄÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇÑ, aaaaaeeeeiiiiooooouuuucnAAAAAEEEEIIIIOOOOOUUUUCN) AS customer_state#57, created_at#54, updated_at#55, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                         +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#49, translate(customer_city#52, áàâãäéèêëíìîïóòôõöúùûüçñÁÀÂÃÄÉÈÊËÍÌÎÏÓÒÔÕÖÚÙÛÜÇÑ, aaaaaeeeeiiiiooooouuuucnAAAAAEEEEIIIIOOOOOUUUUCN) AS customer_city#56, customer_state#53, created_at#54, updated_at#55, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                            +- Filter ((updated_at#55 >= cast(2000-01-01 as timestamp)) AND (updated_at#55 <= cast(current_timestamp() + INTERVAL '1' DAY as timestamp)))
#                               +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#49, customer_city#52, customer_state#53, created_at#54, cast((cast(updated_at#31L as double) / cast(1000000 as double)) as timestamp) AS updated_at#55, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                  +- Filter ((created_at#54 >= cast(2000-01-01 as timestamp)) AND (created_at#54 <= cast(current_timestamp() + INTERVAL '1' DAY as timestamp)))
#                                     +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#49, customer_city#52, customer_state#53, cast((cast(created_at#30L as double) / cast(1000000 as double)) as timestamp) AS created_at#54, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                        +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#49, customer_city#52, upper(customer_state#51) AS customer_state#53, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                           +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#49, initcap(customer_city#50) AS customer_city#52, customer_state#51, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                              +- Project [customer_id#40, customer_unique_id#42, coalesce(customer_zip_code_prefix#44, cast(N/A as string)) AS customer_zip_code_prefix#49, coalesce(customer_city#46, cast(N/A as string)) AS customer_city#50, coalesce(customer_state#48, cast(N/A as string)) AS customer_state#51, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                 +- Filter atleastnnonnulls(2, customer_id#40, customer_unique_id#42)
#                                                    +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#44, customer_city#46, trim(customer_state#47, None) AS customer_state#48, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                       +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#44, customer_city#46, regexp_replace(customer_state#29, [\x00-\x08\x0B\x0C\x0E-\x1F\x7F], , 1) AS customer_state#47, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                          +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#44, trim(customer_city#45, None) AS customer_city#46, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                             +- Project [customer_id#40, customer_unique_id#42, customer_zip_code_prefix#44, regexp_replace(customer_city#28, [\x00-\x08\x0B\x0C\x0E-\x1F\x7F], , 1) AS customer_city#45, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                +- Project [customer_id#40, customer_unique_id#42, trim(customer_zip_code_prefix#43, None) AS customer_zip_code_prefix#44, customer_city#28, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                   +- Project [customer_id#40, customer_unique_id#42, regexp_replace(customer_zip_code_prefix#27, [\x00-\x08\x0B\x0C\x0E-\x1F\x7F], , 1) AS customer_zip_code_prefix#43, customer_city#28, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                      +- Project [customer_id#40, trim(customer_unique_id#41, None) AS customer_unique_id#42, customer_zip_code_prefix#27, customer_city#28, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                         +- Project [customer_id#40, regexp_replace(customer_unique_id#26, [\x00-\x08\x0B\x0C\x0E-\x1F\x7F], , 1) AS customer_unique_id#41, customer_zip_code_prefix#27, customer_city#28, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                            +- Project [trim(customer_id#39, None) AS customer_id#40, customer_unique_id#26, customer_zip_code_prefix#27, customer_city#28, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                               +- Project [regexp_replace(customer_id#25, [\x00-\x08\x0B\x0C\x0E-\x1F\x7F], , 1) AS customer_id#39, customer_unique_id#26, customer_zip_code_prefix#27, customer_city#28, customer_state#29, created_at#30L, updated_at#31L, _op#32, cdc_ts_ms#33L, batch_id#34, spark_ingest_ts#35, cdc_op#36, cdc_ts#37, ds#38]
#                                                                                  +- Project [customer_id#0 AS customer_id#25, customer_unique_id#1 AS customer_unique_id#26, customer_zip_code_prefix#2 AS customer_zip_code_prefix#27, customer_city#3 AS customer_city#28, customer_state#4 AS customer_state#29, created_at#5L AS created_at#30L, updated_at#6L AS updated_at#31L, __op#7 AS _op#32, cdc_ts_ms#22L AS cdc_ts_ms#33L, batch_id#12 AS batch_id#34, spark_ingest_ts#13 AS spark_ingest_ts#35, cdc_op#21 AS cdc_op#36, cdc_ts#23 AS cdc_ts#37, ds#24 AS ds#38]
#                                                                                     +- Project [customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, cdc_ts_ms#22L, batch_id#12, spark_ingest_ts#13, cdc_op#21, cdc_ts#23, ds#24]
#                                                                                        +- Project [customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, cdc_ts_ms#22L, batch_id#12, spark_ingest_ts#13, cdc_op#21, cdc_ts#23, ds#24]
#                                                                                           +- Project [customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, cdc_ts_ms#22L, kafka_offset#9L, kafka_partition#10, kafka_ingest_ts#11, batch_id#12, spark_ingest_ts#13, cdc_op#21, cdc_ts#23, to_date(cdc_ts#23, None, Some(UTC), true) AS ds#24]
#                                                                                              +- Project [customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, cdc_ts_ms#22L, kafka_offset#9L, kafka_partition#10, kafka_ingest_ts#11, batch_id#12, spark_ingest_ts#13, cdc_op#21, to_timestamp((cast(cdc_ts_ms#22L as double) / cast(1000 as double)), None, TimestampType, Some(UTC), true) AS cdc_ts#23]
#                                                                                                 +- Project [customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, __ts_ms#8L AS cdc_ts_ms#22L, kafka_offset#9L, kafka_partition#10, kafka_ingest_ts#11, batch_id#12, spark_ingest_ts#13, cdc_op#21]
#                                                                                                    +- Project [customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, __ts_ms#8L, kafka_offset#9L, kafka_partition#10, kafka_ingest_ts#11, batch_id#12, spark_ingest_ts#13, CASE WHEN (__op#7 = r) THEN c ELSE __op#7 END AS cdc_op#21]
#                                                                                                       +- SubqueryAlias polaris.bronze.customers
#                                                                                                          +- RelationV2[customer_id#0, customer_unique_id#1, customer_zip_code_prefix#2, customer_city#3, customer_state#4, created_at#5L, updated_at#6L, __op#7, __ts_ms#8L, kafka_offset#9L, kafka_partition#10, kafka_ingest_ts#11, batch_id#12, spark_ingest_ts#13] polaris.bronze.customers polaris.bronze.customers

# %% [markdown]
# ## Sanity Check

# %%
for table_name in TABLE_TRANSFORMS:
    df = spark.table(f"{CATALOG}.{MONITORING_NAMESPACE}.{table_name}").limit(5)
    df.show()

# %%
df = spark.table(f"{CATALOG}.{MONITORING_NAMESPACE}.dq_metrics").limit(5)
df.show()

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
