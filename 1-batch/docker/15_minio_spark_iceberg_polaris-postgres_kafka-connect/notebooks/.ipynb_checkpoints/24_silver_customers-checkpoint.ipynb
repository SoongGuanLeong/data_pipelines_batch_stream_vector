# %% [markdown]
# # Silver Customers

# %% [markdown]
# ## Import Helper Functions

# %%
from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["silver"])
        .getOrCreate()
)

# %% [markdown]
# ## Identify Config

# %%
## These are the variable/config to extract out so that this notebook is reusable

# bronze_df = spark.table("polaris.bronze.customers")
# PRIMARY_KEY = "customer_id"
# SILVER_TABLE = "polaris.silver.customers"

# %% [markdown]
# ## Read from Bronze

# %%
bronze_df = spark.table("polaris.bronze.customers")
bronze_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- __op: string (nullable = true)
#  |-- __ts_ms: long (nullable = true)
#  |-- kafka_offset: long (nullable = true)
#  |-- kafka_partition: integer (nullable = true)
#  |-- kafka_ingest_ts: timestamp (nullable = true)
#  |-- batch_id: string (nullable = true)
#  |-- spark_ingest_ts: timestamp (nullable = true)

# %% [markdown]
# ## Treat Snapshot Read as "Create"

# %%
silver_ready_df = (
    bronze_df
    .withColumn(
        "cdc_op",
        F.when(F.col("__op") == "r", F.lit("c"))
         .otherwise(F.col("__op"))
    )
    .withColumnRenamed("__ts_ms", "cdc_ts_ms")
)

# %% [markdown]
# ## Dedup per Key

# %%
PRIMARY_KEY = "customer_id"

w = (
    W.partitionBy(PRIMARY_KEY)
    .orderBy(F.col("cdc_ts_ms").desc(), F.col("kafka_offset").desc())
)

silver_dedup_df = (
    silver_ready_df
    .withColumn("row_num", F.row_number().over(w))
    .filter(F.col("row_num") == 1)
    .drop("row_num")
)

# %% [markdown]
# ## Drop CDC Metadata Column

# %%
CDC_METADATA_COLS = {
    "__op",
    "kafka_offset",
    "kafka_partition",
    "kafka_ingest_ts",
    "batch_id",
    "spark_ingest_ts"
}

final_cols = [c for c in silver_dedup_df.columns if c not in CDC_METADATA_COLS]

final_silver_df = silver_dedup_df.select(*final_cols)
final_silver_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- cdc_ts_ms: long (nullable = true)
#  |-- cdc_op: string (nullable = true)

# %% [markdown]
# ## Add SCD2 Columns

# %%
business_cols = final_silver_df.columns
SCD2_COLS = {"effective_from", "effective_to", "is_current"}

scd2_df = (
    final_silver_df
    .withColumn("effective_from", F.current_timestamp())
    .withColumn("effective_to", F.lit(None).cast("timestamp"))
    .withColumn("is_current", F.lit(True))
    .withColumn("row_hash", F.sha2(F.concat_ws("||", *business_cols), 256))
)

# %% [markdown]
# ## Detect Schema Drift

# %%
from pyspark.sql.utils import AnalysisException

SILVER_TABLE = "polaris.silver.customers"

# ---- Detect table existence ----
try:
    silver_existing_df = spark.table(SILVER_TABLE)
except AnalysisException:
    scd2_df.writeTo(SILVER_TABLE).using("iceberg").create()
    silver_existing_df = spark.table(SILVER_TABLE)

# ---- Drift Detection ----
incoming_cols = set(scd2_df.columns)
existing_cols = set(silver_existing_df.columns)

new_cols = incoming_cols - existing_cols
missing_cols = existing_cols - incoming_cols

if missing_cols:
    raise Exception(f"Destructive schema change detected: {missing_cols}")

# ---- Additive evolution ----
for col in new_cols:
    dtype = scd2_df.schema[col].dataType.simpleString()
    spark.sql(f"""
        ALTER TABLE {SILVER_TABLE} 
        ADD COLUMN {col} {dtype}
    """)

# %% [markdown]
# ## SCD2 Merge

# %%
scd2_df.createOrReplaceTempView("source_updates")

spark.sql(f"""
MERGE INTO {SILVER_TABLE} AS target
USING source_updates AS source
ON target.{PRIMARY_KEY} = source.{PRIMARY_KEY}
   AND target.is_current = true

WHEN MATCHED AND target.row_hash <> source.row_hash THEN
  UPDATE SET
    target.effective_to = current_timestamp(),
    target.is_current = false

WHEN NOT MATCHED THEN
  INSERT *
""")
# Out:
# DataFrame[]
