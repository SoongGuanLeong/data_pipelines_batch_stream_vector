# %% [markdown]
# # Init Lakehouse

# %% [markdown]
# ## Import Config

# %%
from config import *

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["init_lakehouse"])
        .getOrCreate()
)

# Load the Spark SQL magic created earlier
from spark_sql_magic import sql  # registers the %%sql magic automatically
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Select Catalog

# %%
spark.sql(f"USE {CATALOG};")
# Out:
# DataFrame[]

# %% [markdown]
# ## Create Lakehouse Namespace

# %%
NAMESPACES = [BRONZE_NAMESPACE, SILVER_NAMESPACE, GOLD_NAMESPACE]

for ns in NAMESPACES:
    spark.sql(f"CREATE NAMESPACE IF NOT EXISTS {ns};")

# %%
# %%sql
# SHOW NAMESPACES;
# Out:
# +---------+
# |namespace|
# +---------+
# |bronze   |
# |gold     |
# |silver   |
# +---------+

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
