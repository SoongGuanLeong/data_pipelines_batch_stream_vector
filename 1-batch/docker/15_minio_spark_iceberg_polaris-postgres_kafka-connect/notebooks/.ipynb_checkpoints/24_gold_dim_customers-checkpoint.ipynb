# %% [markdown]
# # Gold: dim_customers

# %% [markdown]
# ## Import Helper Functions

# %%
from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# from src.config_loader import load_config
# from src.spark_sql_magic import sql
# from src.gold.dims.customers import build_dim_customers_scd2, build_incremental_dim_customers, validate_scd2_customers
# from src.watermark import  get_last_commit_ts, get_effective_watermark, get_changed_keys
# from src.writer import overwrite_table, replace_by_key
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
SILVER_NAMESPACE = cfg["general"]["namespaces"]["silver"]
GOLD_NAMESPACE = cfg["general"]["namespaces"]["gold"]

cfg_cust= cfg["gold"]["dim_customers_scd2"]
SOURCE_TABLE = cfg_cust["source_table"]
TARGET_TABLE = cfg_cust["target_table"]
GEO_TABLE = cfg_cust["geo_table"]
BUFFER_HOURS = cfg_cust["buffer_hours"]
KEY_COLUMN = cfg_cust["key_column"]

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["gold_customers"])
        .getOrCreate()
)

# %% [markdown]
# ## Run Pipeline

# %%
def run_dim_customers_pipeline(spark):
    print("[START] dim_customers pipeline")
    
    last_commit_ts = get_last_commit_ts(spark, TARGET_TABLE)
    print(f"[INFO] last_commit_ts = {last_commit_ts}")
    
    if last_commit_ts is None:
        print("[INFO] first run → full rebuild")
        df = build_dim_customers_scd2(spark, SOURCE_TABLE, GEO_TABLE)
        validate_scd2_customers(df)
        overwrite_table(df, TARGET_TABLE)
        print("[END] full rebuild complete")
        return

    effective_ts = get_effective_watermark(last_commit_ts, BUFFER_HOURS)
    changed_customer_ids = get_changed_keys(spark, SOURCE_TABLE, KEY_COLUMN, effective_ts)

    if changed_customer_ids.isEmpty():
        print("[INFO] no changes detected → skip")
        return
    print("[INFO] changes detected → incremental run")

    df = build_incremental_dim_customers(spark, SOURCE_TABLE, GEO_TABLE, changed_customer_ids)
    validate_scd2_customers(df)
    replace_by_key(spark, df, TARGET_TABLE, KEY_COLUMN)
    print("[END] incremental update complete")

# %%
# if __name__ == "__main__":
#     from pyspark.sql import SparkSession

#     spark = SparkSession.builder.getOrCreate()
run_dim_customers_pipeline(spark)
# Out:
# [START] dim_customers pipeline
# [INFO] last_commit_ts = None
# [INFO] first run → full rebuild
# [END] full rebuild complete

# %% [markdown]
# ## Sanity Check

# %%
# %%sql
# SHOW TABLES IN polaris.gold;
# Out:
# +---------+------------------+-----------+
# |namespace|tableName         |isTemporary|
# +---------+------------------+-----------+
# |gold     |dim_customers_scd2|false      |
# +---------+------------------+-----------+

# %%
# %%sql
# SELECT * FROM polaris.gold.dim_customers_scd2
# LIMIT 10
# Out:
# +--------------------------------+--------------------------------+------------------------+-------------------+--------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+------------+----------+----------------------------------------------------------------+
# |customer_id                     |customer_unique_id              |customer_zip_code_prefix|customer_city      |customer_state|geolocation_lat    |geolocation_lng    |cdc_ts                 |spark_ingest_ts        |effective_from         |effective_to|is_current|customer_sk                                                     |
# +--------------------------------+--------------------------------+------------------------+-------------------+--------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+------------+----------+----------------------------------------------------------------+
# |00050bf6e01e69d5c0fd612f1bcfb69c|e3cf594a99e810f58af53ed4820f25e5|98700                   |Ijui               |RS            |-28.387828504120098|-53.91593589989323 |2026-03-27 01:49:50.276|2026-03-27 02:15:52.477|2026-03-27 01:49:50.276|NULL        |true      |df67a680f16142bb210689e6d0ed4aa17260fdd34fb133de10c48f9a03557fd2|
# |000598caf2ef4117407665ac33275130|7e0516b486e92ed3f3afdd6d1276cfbd|35540                   |Oliveira           |MG            |-20.698563939792187|-44.82676038665834 |2026-03-27 01:49:50.276|2026-03-27 02:15:52.477|2026-03-27 01:49:50.276|NULL        |true      |ca4f88cc0aa3784938f94ca8b49804c32b0c8d5b9c62f4e692436aa494e64305|
# |0013cd8e350a7cc76873441e431dd5ee|334fed5abcee3aa96c13f1432703e1fd|03585                   |Sao Paulo          |SP            |-23.5657699974044  |-46.49178572221209 |2026-03-27 01:49:50.285|2026-03-27 02:15:52.477|2026-03-27 01:49:50.285|NULL        |true      |7db8badbcd2ee95413ce0bda8391f9a9c096f2f12ca767fc9a07fc8cf168e0dc|
# |0015bc9fd2d5395446143e8b215d7c75|490c854539b21598cfbbac518ca25788|12233                   |Sao Jose Dos Campos|SP            |-23.246680687314193|-45.88690913568317 |2026-03-27 01:49:50.288|2026-03-27 02:15:52.477|2026-03-27 01:49:50.288|NULL        |true      |aa7804d77fef0c519594fbedb76405f20adc795362147dc0c1fb20ce14cafe1e|
# |001f150aebb5d897f2059b0460c38449|0f88eb431888ffb9d726252b7ac8cefe|79031                   |Campo Grande       |MS            |-20.45170007108882 |-54.57178607131569 |2026-03-27 01:49:50.292|2026-03-27 02:15:52.477|2026-03-27 01:49:50.292|NULL        |true      |b1f9f30e5bc3bf315eba12edb60ca0ce5033405a0c13c70a5f1871c3c018506f|
# |0028ff36263a86bf679df7c863a0a0ba|0659763dba9821af49728668716e1084|28895                   |Rio Das Ostras     |RJ            |-22.507678728605775|-41.924924524617474|2026-03-27 01:49:50.299|2026-03-27 02:15:52.477|2026-03-27 01:49:50.299|NULL        |true      |62fe20ec2e717efa37782d540075c34d8f8725638df8b3ab7df4651bf602c6e8|
# |0037d14e53af1d555a582504a4058f4c|442bdd695caba6183fc44d6cfdd4f094|05857                   |Sao Paulo          |SP            |-23.65678941102508 |-46.78053307135405 |2026-03-27 01:49:50.316|2026-03-27 02:15:52.477|2026-03-27 01:49:50.316|NULL        |true      |8bb4d4d3f975e0c5ca95eeceb3823f52179d27721b08df37aaf0143d622c1185|
# |003c7cadba4f182b9f22d7d5ea7a5003|6279364f420b1e08eb33a498db5fa6bc|03981                   |Sao Paulo          |SP            |-23.613443207749032|-46.5164746607028  |2026-03-27 01:49:50.319|2026-03-27 02:15:52.477|2026-03-27 01:49:50.319|NULL        |true      |0a880a42c967c702b6b93557ab1c5f970512034019d99a983309bacd1f43b629|
# |0040a8417928d0d5abd5169cd7877181|96e147852028a3ce1d25c86f03032023|12288                   |Cacapava           |SP            |-23.0931768072255  |-45.71105364946359 |2026-03-27 01:49:50.324|2026-03-27 02:15:52.477|2026-03-27 01:49:50.324|NULL        |true      |302fd1a81c0c298345dc6f21b1b0f49ec6bb2d02eaef8313835005a58eac4b90|
# |004937d0f9d6ce15c2830c00c2f482e5|a590fdd68e210fa5f42764a2493f6223|14870                   |Jaboticabal        |SP            |-21.25717364466399 |-48.32096387334478 |2026-03-27 01:49:50.33 |2026-03-27 02:15:52.477|2026-03-27 01:49:50.33 |NULL        |true      |d4f80641502662473a8f1c31e4336e0accbc1d8bf51fa4e8f1206ae7dee84e4c|
# +--------------------------------+--------------------------------+------------------------+-------------------+--------------+-------------------+-------------------+-----------------------+-----------------------+-----------------------+------------+----------+----------------------------------------------------------------+

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
