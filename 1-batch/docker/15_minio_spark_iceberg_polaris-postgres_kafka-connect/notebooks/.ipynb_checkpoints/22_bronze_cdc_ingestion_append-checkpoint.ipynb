# %% [markdown]
# # Bronze CDC Ingestion

# %% [markdown]
# ## Import Helper Functions

# %%
from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# from src.config_loader import load_config
# from src.spark_sql_magic import sql
# from src.avro_utils import fetch_avro_schema
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
BRONZE_NAMESPACE = cfg["general"]["namespaces"]["bronze"]
CHECKPOINT_BASE = cfg["kafka"]["checkpoint_base"]
KAFKA_BOOTSTRAP = cfg["kafka"]["bootstrap_servers"]
TOPIC_PREFIX = cfg["kafka"]["topic_prefix"]
TOPIC_SUFFIX = set(cfg["kafka"]["topic_suffix"])
APICURIO_URL = cfg["api"]["apicurio_url"]

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["bronze_cdc_ingestion_backfill"])
        .getOrCreate()
)

# %% [markdown]
# ## Read Kafka Stream for all topics

# %%
kafka_df = (
    spark.readStream
        .format("kafka")
        .option("kafka.bootstrap.servers", KAFKA_BOOTSTRAP)
        .option("subscribePattern", f"{TOPIC_PREFIX}\\..*")    # <- dynamic subscription
        .option("startingOffsets", "latest")
        .load()
)

# %% [markdown]
# ## Rename Columns and add timestamp

# %%
kafka_df = (
    kafka_df
    .withColumn("raw_value", F.col("value"))
    .withColumn("spark_ingest_ts", F.current_timestamp())
    .withColumnRenamed("offset", "kafka_offset")
    .withColumnRenamed("partition", "kafka_partition")
    .withColumnRenamed("timestamp", "kafka_ingest_ts")
)

# %% [markdown]
# ## Function: foreachBatch writer

# %%
from pyspark.sql.avro.functions import from_avro

def write_batch(batch_df, batch_id):
    if batch_df.isEmpty():
        return

    batch_df = (
        batch_df.withColumn("batch_id", F.lit(str(batch_id)))
        .withColumn("topic_suffix", F.regexp_extract(F.col("topic"), r"[^.]+$", 0))
    ).persist()

    # Process per topic dynamically
    topics = [r.topic_suffix for r in batch_df.select("topic_suffix").distinct().collect()]

    for topic in topics:
        topic_df = batch_df.filter(F.col("topic_suffix") == topic)
        table_name = f"{CATALOG}.{BRONZE_NAMESPACE}.{topic}"
        dlq_table = f"{CATALOG}.{BRONZE_NAMESPACE}_dlq.{topic}_dlq"
        audit_table = f"{CATALOG}.{BRONZE_NAMESPACE}_audit.{topic}_audit"

        schema_dict = fetch_avro_schema(topic, APICURIO_URL, TOPIC_PREFIX)
        schema_json = json.dumps(schema_dict)

        decoded_df = topic_df.select(
            from_avro("raw_value", schema_json, {"mode": "PERMISSIVE"}).alias("data"),
            "raw_value",
            "kafka_offset",
            "kafka_partition",
            "kafka_ingest_ts",
            "spark_ingest_ts",
            "batch_id"
        )

        valid_df = decoded_df.filter(F.col("data").isNotNull())
        dlq_df   = decoded_df.filter(F.col("data").isNull())

        valid_df = (
            valid_df
            .select("data.*", "kafka_offset", "kafka_partition", "kafka_ingest_ts", "spark_ingest_ts", "batch_id")
        )

        dlq_df = (
            dlq_df
            .select("raw_value", "kafka_offset", "kafka_partition", "kafka_ingest_ts", "spark_ingest_ts", "batch_id")
        )

        # --- Write bronze and DLQ ---
        valid_df.write.format("iceberg").mode("append").option("mergeSchema", "true").saveAsTable(table_name)
        dlq_df.write.format("iceberg").mode("append").saveAsTable(dlq_table)

        # --- Audit ---
        audit_partition_df = topic_df.groupBy("kafka_partition").agg(
            F.lit(f"{TOPIC_PREFIX}.{topic}").alias("topic"),
            F.lit(str(batch_id)).alias("batch_id"),
            F.current_timestamp().alias("batch_ts"),
            F.min("kafka_offset").alias("min_offset"),
            F.max("kafka_offset").alias("max_offset"),
            F.count("*").alias("row_count")
        )
        audit_partition_df.write.format("iceberg").mode("append").saveAsTable(audit_table)

    # Clean up persistence
    batch_df.unpersist()

# %% [markdown]
# ## Start Streams

# %%
query = (
    kafka_df.writeStream
        .foreachBatch(write_batch)
        .option("checkpointLocation", f"{CHECKPOINT_BASE}/{BRONZE_NAMESPACE}/all_topics")
        .trigger(availableNow=True)  # Databricks-friendly
        .start()
)

query.awaitTermination()

# %% [markdown]
# ## Sanity Check Show All Tables

# %%
# %%sql
# SHOW TABLES IN bronze;
# SHOW TABLES IN bronze_audit;
# SHOW TABLES IN bronze_dlq;
# Out:
# +---------+--------------+-----------+
# |namespace|tableName     |isTemporary|
# +---------+--------------+-----------+
# |bronze   |order_payments|false      |
# |bronze   |orders        |false      |
# |bronze   |order_reviews |false      |
# |bronze   |customers     |false      |
# |bronze   |products      |false      |
# |bronze   |order_items   |false      |
# |bronze   |sellers       |false      |
# +---------+--------------+-----------+
#
# +------------+--------------------+-----------+
# |namespace   |tableName           |isTemporary|
# +------------+--------------------+-----------+
# |bronze_audit|order_items_audit   |false      |
# |bronze_audit|sellers_audit       |false      |
# |bronze_audit|order_payments_audit|false      |
# |bronze_audit|orders_audit        |false      |
# |bronze_audit|order_reviews_audit |false      |
# |bronze_audit|customers_audit     |false      |
# |bronze_audit|products_audit      |false      |
# +------------+--------------------+-----------+
#
# +----------+------------------+-----------+
# |namespace |tableName         |isTemporary|
# +----------+------------------+-----------+
# |bronze_dlq|order_payments_dlq|false      |
# |bronze_dlq|orders_dlq        |false      |
# |bronze_dlq|order_reviews_dlq |false      |
# |bronze_dlq|customers_dlq     |false      |
# |bronze_dlq|products_dlq      |false      |
# |bronze_dlq|order_items_dlq   |false      |
# |bronze_dlq|sellers_dlq       |false      |
# +----------+------------------+-----------+

# %%
for item in TOPIC_SUFFIX:
    df = spark.table(f"{CATALOG}.{BRONZE_NAMESPACE}.{item}").limit(5)
    df.show()
    df = spark.table(f"{CATALOG}.{BRONZE_NAMESPACE}_audit.{item}_audit").limit(5)
    df.show()
# Out:
# +--------------------+----------------------+-----------+------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |           seller_id|seller_zip_code_prefix|seller_city|seller_state|      created_at|      updated_at|__op|      __ts_ms|kafka_offset|kafka_partition|     kafka_ingest_ts|batch_id|     spark_ingest_ts|
# +--------------------+----------------------+-----------+------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |f235413f677777a07...|                 17250|     bariri|          SP|1766340942943182|1766340942943182|   r|1772975551021|           0|              0|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |53e4c6e0f4312d4d2...|                 13920|   pedreira|          SP|1766340942943182|1766340942943182|   r|1772975551021|           1|              0|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |d263fa444c1504a75...|                 13478|  americana|          SP|1766340942943182|1766340942943182|   r|1772975551021|           2|              0|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |39a5005f2605cbdb4...|                 14780|   barretos|          SP|1766340942943182|1766340942943182|   r|1772975551021|           3|              0|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |08061dc0fc165ed41...|                 06036|     osasco|          SP|1766340942943182|1766340942943182|   r|1772975551021|           4|              0|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# +--------------------+----------------------+-----------+------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
#
# +---------------+------------------+--------+--------------------+----------+----------+---------+
# |kafka_partition|             topic|batch_id|            batch_ts|min_offset|max_offset|row_count|
# +---------------+------------------+--------+--------------------+----------+----------+---------+
# |              1|olist.oltp.sellers|       0|2026-03-09 00:03:...|         0|      1022|     1023|
# |              2|olist.oltp.sellers|       0|2026-03-09 00:03:...|         0|      1036|     1037|
# |              0|olist.oltp.sellers|       0|2026-03-09 00:03:...|         0|      1034|     1035|
# +---------------+------------------+--------+--------------------+----------+----------+---------+
#
# +--------------------+------------------+------------+--------------------+---------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |            order_id|payment_sequential|payment_type|payment_installments|  payment_value|      created_at|      updated_at|__op|      __ts_ms|kafka_offset|kafka_partition|     kafka_ingest_ts|batch_id|     spark_ingest_ts|
# +--------------------+------------------+------------+--------------------+---------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |771ee386b001f0620...|                 1| credit_card|                   1|   {2, [1F B4]}|1766341498948202|1766341498948202|   r|1772975536695|           0|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |1f78449c87a54faf9...|                 1| credit_card|                   6|{2, [00 85 3D]}|1766341498948202|1766341498948202|   r|1772975536695|           1|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |cf95215a722f3ebf2...|                 1| credit_card|                   5|   {2, [28 1A]}|1766341498948202|1766341498948202|   r|1772975536695|           2|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |769214176682788a9...|                 1| credit_card|                   4|   {2, [29 20]}|1766341498948202|1766341498948202|   r|1772975536695|           3|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |61059985a6fc0ad64...|                 1| credit_card|                   1|   {2, [33 94]}|1766341498948202|1766341498948202|   r|1772975536695|           4|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# +--------------------+------------------+------------+--------------------+---------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
#
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
# |kafka_partition|               topic|batch_id|            batch_ts|min_offset|max_offset|row_count|
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
# |              1|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     34477|    34478|
# |              2|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     34606|    34607|
# |              0|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     34800|    34801|
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
#
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |           review_id|            order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|      created_at|      updated_at|__op|      __ts_ms|kafka_offset|kafka_partition|     kafka_ingest_ts|batch_id|     spark_ingest_ts|
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |f7c4243c7fe1938f1...|8e6bfb81e283fa7e4...|           5|                NULL|  Parabéns lojas la...|    1519862400000000|       1519986413000000|1766341512825786|1766341512825786|   r|1772975540668|           0|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |07f9bee5d1b850860...|e48aa0d2dcec3a2e8...|           5|                NULL|                  NULL|    1500163200000000|       1500406234000000|1766341512825786|1766341512825786|   r|1772975540668|           1|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |7c6400515c67679fb...|c31a859e34e3adac2...|           5|                NULL|                  NULL|    1534204800000000|       1534282566000000|1766341512825786|1766341512825786|   r|1772975540668|           2|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |a3f6f7f6f433de0ae...|9c214ac970e842735...|           5|                NULL|                  NULL|    1494979200000000|       1495109137000000|1766341512825786|1766341512825786|   r|1772975540668|           3|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |8670d52e15e00043a...|b9bf720beb4ab3728...|           4|           recomendo|  aparelho eficient...|    1526947200000000|       1527093947000000|1766341512825786|1766341512825786|   r|1772975540668|           4|              2|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
#
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
# |kafka_partition|               topic|batch_id|            batch_ts|min_offset|max_offset|row_count|
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
# |              1|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     32905|    32906|
# |              2|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     32881|    32882|
# |              0|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     32621|    32622|
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
#
# +--------------------+--------------------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date
              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |a556987a68ce3f724...|                artes|                 55|                       351|                 2|    {0, [06 72]}|        {0, [2E]}|        {0, [0A]}|       {0, [0B]}|1766341449649871|1766341449649871|   r|1772975549701|           1|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |79a8800eb81425242...|         beleza_saude|                 40|                       707|                 1|    {0, [01 B6]}|        {0, [15]}|        {0, [13]}|       {0, [13]}|1766341449649871|1766341449649871|   r|1772975549701|           2|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |5e56d835ab5e03bad...|           cool_stuff|                 45|                      1676|                 2|    {0, [01 F4]}|        {0, [10]}|        {0, [03]}|       {0, [14]}|1766341449649871|1766341449649871|   r|1772975549701|           3|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |2284b28ca179d6695...| utilidades_domest...|                 54|                       408|                 1|    {0, [06 40]}|        {0, [22]}|        {0, [15]}|       {0, [17]}|1766341449649871|1766341449649871|   r|1772975549701|           4|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
#
# +---------------+-------------------+--------+--------------------+----------+----------+---------+
# |kafka_partition|              topic|batch_id|            batch_ts|min_offset|max_offset|row_count|
# +---------------+-------------------+--------+--------------------+----------+----------+---------+
# |              1|olist.oltp.products|       0|2026-03-09 00:03:...|         0|     11112|    11113|
# |              2|olist.oltp.products|       0|2026-03-09 00:03:...|         0|     10950|    10951|
# |              0|olist.oltp.products|       0|2026-03-09 00:03:...|         0|     10886|    10887|
# +---------------+-------------------+--------+--------------------+----------+----------+---------+
#
# +--------------------+-------------+--------------------+--------------------+-------------------+------------+-------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |            order_id|order_item_id|          product_id|           seller_id|shipping_limit_date|       price|freight_value|      created_at|      updated_at|__op|      __ts_ms|kafka_offset|kafka_partition|     kafka_ingest_ts|batch_id|     spark_ingest_ts|
# +--------------------+-------------+--------------------+--------------------+-------------------+------------+-------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
# |00010242fe8c5a6d1...|            1|4244733e06e7ecb49...|48436dade18ac8b2b...|   1505814335000000|{1, [02 4D]}| {2, [05 31]}|1766341481729495|1766341481729495|   r|1772975531295|           0|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |00018f77f2f0320c5...|            1|e5f2d52b802189ee6...|dd7ddc04e1b6c2c61...|   1493809513000000|{1, [09 5F]}| {2, [07 C9]}|1766341481729495|1766341481729495|   r|1772975531295|           1|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |00042b26cf59d7ce6...|            1|ac6c3623068f30de0...|df560393f3a51e745...|   1486994271000000|{1, [07 CF]}| {2, [07 16]}|1766341481729495|1766341481729495|   r|1772975531297|           2|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |0005a1a1728c9d785...|            1|310ae3c140ff94b03...|a416b6a846a117243...|   1522089089000000|{2, [39 03]}| {2, [04 8D]}|1766341481729495|1766341481729495|   r|1772975531297|           3|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# |00061f2a7bc09da83...|            1|d63c1011f49d98b97...|cc419e0650a3c5ba7...|   1522362489000000|{2, [17 6F]}| {2, [03 78]}|1766341481729495|1766341481729495|   r|1772975531298|           4|              1|2026-03-08 13:12:...|       0|2026-03-09 00:03:...|
# +--------------------+-------------+--------------------+--------------------+-------------------+------------+-------------+----------------+----------------+----+-------------+------------+---------------+--------------------+--------+--------------------+
#
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
# |kafka_partition|               topic|batch_id|            batch_ts|min_offset|max_offset|row_count|
# +---------------+--------------------+--------+--------------------+----------+----------+---------+
# |              1|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     37495|    37496|
# |              2|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     37444|    37445|
# |              0|olist.oltp.order_...|       0|2026-03-09 00:03:...|         0|     37708|    37709|
# +---------------+--------------------+--------+--------------------+----------+----------+---------+

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
