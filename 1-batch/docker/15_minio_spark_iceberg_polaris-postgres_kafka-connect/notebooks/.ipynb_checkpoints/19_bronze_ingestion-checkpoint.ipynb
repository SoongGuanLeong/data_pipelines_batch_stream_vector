# %% [markdown]
# # Bronze Layer Ingestion

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName("olist-bronze-setup")
        .getOrCreate()
)

# Load the Spark SQL magic python file created earlier
from spark_sql_magic import sql  # registers the %%sql magic automatically
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# [12:56:33] [Thread-3] WARN  org.apache.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Test CDC Ingestion Once

# %% [markdown]
# ## Read from Kafka Batch

# %%
# BATCH LOAD CDC table ONCE to check the code.

df_kafka = (
    spark.read
    .format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "olist.oltp.customers")
    .option("startingOffsets", "earliest")
    .load()
)

# %%
df_kafka.printSchema()
# we need value, partition, offset and timestamp
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %% [markdown]
# ## Ingestion Schema: Fetch via REST API

# %%
import requests

response = requests.get(
    "http://apicurio:8081/apis/registry/v2/groups/default/artifacts/olist.oltp.customers-value/versions/latest",
    timeout = 10
)
response.raise_for_status()

schema_dict = response.json()
schema_dict
# Out:
# {'type': 'record',
#  'name': 'Value',
#  'namespace': 'olist.oltp.customers',
#  'fields': [{'name': 'customer_id', 'type': 'string'},
#   {'name': 'customer_unique_id', 'type': ['null', 'string'], 'default': None},
#   {'name': 'customer_zip_code_prefix',
#    'type': ['null', 'string'],
#    'default': None},
#   {'name': 'customer_city', 'type': ['null', 'string'], 'default': None},
#   {'name': 'customer_state', 'type': ['null', 'string'], 'default': None},
#   {'name': 'created_at',
#    'type': [{'type': 'long',
#      'connect.version': 1,
#      'connect.default': 0,
#      'connect.name': 'io.debezium.time.MicroTimestamp'},
#     'null'],
#    'default': 0},
#   {'name': 'updated_at',
#    'type': [{'type': 'long',
#      'connect.version': 1,
#      'connect.default': 0,
#      'connect.name': 'io.debezium.time.MicroTimestamp'},
#     'null'],
#    'default': 0},
#   {'name': '__op', 'type': ['null', 'string'], 'default': None},
# ...

# %%
# convert to json string
schema_json = json.dumps(schema_dict)
schema_json
# Out:
# '{"type": "record", "name": "Value", "namespace": "olist.oltp.customers", "fields": [{"name": "customer_id", "type": "string"}, {"name": "customer_unique_id", "type": ["null", "string"], "default": null}, {"name": "customer_zip_code_prefix", "type": ["null", "string"], "default": null}, {"name": "customer_city", "type": ["null", "string"], "default": null}, {"name": "customer_state", "type": ["null", "string"], "default": null}, {"name": "created_at", "type": [{"type": "long", "connect.version": 1, "connect.default": 0, "connect.name": "io.debezium.time.MicroTimestamp"}, "null"], "default": 0}, {"name": "updated_at", "type": [{"type": "long", "connect.version": 1, "connect.default": 0, "connect.name": "io.debezium.time.MicroTimestamp"}, "null"], "default": 0}, {"name": "__op", "type": ["null", "string"], "default": null}, {"name": "__ts_ms", "type": ["null", "long"], "default": null}], "connect.name": "olist.oltp.customers.Value"}'

# %% [markdown]
# ## Generate a unique batch_id with python

# %%
# this is needed for Spark streaming foreachBatch
import datetime, uuid

batch_id = f"{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}-{uuid.uuid4().hex[:8]}"

# %% [markdown]
# ## Deserialize/Parse Avro

# %%
from pyspark.sql.avro.functions import from_avro

df_parsed = (
    df_kafka
        .select(
            from_avro("value", schema_json).alias("data"),
            F.col("offset"),
            F.col("partition"),
            F.col("timestamp").alias("kafka_ingest_ts")
        )
        .select("data.*", "offset", "partition", "kafka_ingest_ts")
        .withColumnRenamed("created_at", "pg_created_at")
        .withColumnRenamed("updated_at", "pg_updated_at")
        .withColumnRenamed("__ts_ms", "pg_commit_ts")
        .withColumn("batch_id", F.lit(batch_id))
        .withColumn("spark_ingest_ts", F.current_timestamp())
)

# %%
df_parsed.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- pg_created_at: long (nullable = true)
#  |-- pg_updated_at: long (nullable = true)
#  |-- __op: string (nullable = true)
#  |-- pg_commit_ts: long (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- kafka_ingest_ts: timestamp (nullable = true)
#  |-- batch_id: string (nullable = false)
#  |-- spark_ingest_ts: timestamp (nullable = false)

# %% [markdown]
# ## Write into Bronze Test Table

# %%
# https://iceberg.apache.org/docs/latest/spark-structured-streaming/
# write > writeStream
# add checkpoint s3a://olist-ecommerce/checkpoints/bronze/customers/
# mode > outputMode
# saveAsTable > toTable

(
    df_parsed.write
    .format("iceberg")
    .mode("append")
    .saveAsTable("polaris.bronze.test_customers")
)
# Out:
# [12:58:11] [Thread-3] INFO  org.apache.iceberg.rest.auth.AuthManagers - Loading AuthManager implementation: org.apache.iceberg.rest.auth.OAuth2Manager
# [12:58:13] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [12:58:16] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties set at catalog level through catalog properties: {}
# [12:58:16] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties enforced at catalog level through catalog properties: {}
# [12:58:18] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [12:58:44] [Thread-3] INFO  org.apache.iceberg.spark.source.SparkWrite - Committing append with 3 new data files to table polaris.bronze.test_customers
# [12:58:45] [Thread-3] INFO  org.apache.iceberg.SnapshotProducer - Committed snapshot 2990712462584461644 (MergeAppend)
# ...

# %%
# %%sql
# DROP TABLE IF EXISTS polaris.bronze.test_customers;
# Out:
# [12:59:02] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO

# %% [markdown]
# ## Define Ingestion Configuration

# %%
INGESTION_CONFIG = [
    "customers",
    "order_items",
    "order_payments",
    "order_reviews",
    "orders",
    "products",
    "sellers"
]

# %%
queries = []

for item in INGESTION_CONFIG:
    print(f"Ingesting topic olist.oltp.{item} → polaris.bronze.{item}")

    df_kafka = (
        spark.readStream
        .format("kafka")
        .option("kafka.bootstrap.servers", "kafka:9092")
        .option("subscribe", f"olist.oltp.{item}")
        .option("startingOffsets", "earliest")
        .load()
    )

    response = requests.get(
        f"http://apicurio:8081/apis/registry/v2/groups/default/artifacts/olist.oltp.{item}-value/versions/latest",
        timeout = 10
    )
    response.raise_for_status()

    schema_dict = response.json()
    schema_json = json.dumps(schema_dict)

    df_parsed = (
        df_kafka
            .select(
                from_avro("value", schema_json).alias("data"),
                F.col("offset"),
                F.col("partition"),
                F.col("timestamp").alias("kafka_ingest_ts")
            )
            .select("data.*", "offset", "partition", "kafka_ingest_ts")
            .withColumnRenamed("created_at", "pg_created_at")
            .withColumnRenamed("updated_at", "pg_updated_at")
            .withColumnRenamed("__ts_ms", "pg_commit_ts")
    )

    def build_write_batch(table_name):
        def write_batch(batch_df, epoch_id):
    
            import uuid, datetime
        
            batch_id = f"{datetime.datetime.now().strftime('%Y%m%d%H%M%S')}-{uuid.uuid4().hex[:8]}"
        
            (
                batch_df
                .withColumn("batch_id", F.lit(batch_id))
                .withColumn("spark_ingest_ts", F.current_timestamp())
                .writeTo(table_name)
                .append()
            )
        return write_batch

    
    query = (
        df_parsed.writeStream
        .foreachbatch(build_write_batch(f"polaris.bronze.{item}"))
        .option("checkpointLocation", f"s3a://olist-ecommerce/checkpoints/bronze/{item}/")
        .start()
    )

    queries.append(query)

try:
    spark.streams.awaitAnyTermination()
except Exception:
    print("Stream failure detected. Shutting down...")
    
    for q in spark.streams.active:
        q.stop()
    
    raise
# Out:
# Ingesting topic olist.oltp.customers → polaris.bronze.customers
# [13:11:41] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties set at catalog level through catalog properties: {}
# [13:11:41] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties enforced at catalog level through catalog properties: {}
# [13:11:42] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [13:11:43] [Thread-3] WARN  org.apache.hadoop.metrics2.impl.MetricsConfig - Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# [13:11:44] [Thread-3] WARN  org.apache.spark.sql.execution.streaming.ResolveWriteToStream - spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Ingesting topic olist.oltp.order_items → polaris.bronze.order_items
# ...

# %% [markdown]
# ## Sanity Check Show All Tables

# %%
# %%sql
# SHOW TABLES IN bronze;
# Out:
# +---------+--------------+-----------+
# |namespace|tableName     |isTemporary|
# +---------+--------------+-----------+
# |bronze   |orders        |false      |
# |bronze   |order_payments|false      |
# |bronze   |products      |false      |
# |bronze   |sellers       |false      |
# |bronze   |customers     |false      |
# |bronze   |order_items   |false      |
# |bronze   |order_reviews |false      |
# +---------+--------------+-----------+

# %%
for item in INGESTION_CONFIG:
    df = spark.table(f"polaris.bronze.{item}").limit(5)
    df.show()
# Out:
# [13:12:22] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [13:12:23] [Thread-3] INFO  org.apache.iceberg.SnapshotScan - Scanning table polaris.bronze.customers snapshot 3953651132620126526 created at 2026-02-14T13:11:59.148+00:00 with filter true
# [13:12:23] [Thread-3] INFO  org.apache.iceberg.BaseDistributedDataScan - Planning file tasks locally for table polaris.bronze.customers
# ...

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
