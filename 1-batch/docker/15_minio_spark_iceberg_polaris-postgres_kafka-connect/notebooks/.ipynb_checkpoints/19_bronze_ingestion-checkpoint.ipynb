# %% [markdown]
# # Bronze Layer Ingestion

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName("olist-bronze-setup")
        .getOrCreate()
)

# Load the Spark SQL magic python file created earlier
from spark_sql_magic import sql  # registers the %%sql magic automatically
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# [08:40:17] [Thread-3] WARN  org.apache.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Read from Kafka Batch

# %%
# BATCH LOAD ONCE for once table to check the code.

df_kafka = (
    spark.read
    .format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "olist.oltp.customers")
    .option("startingOffsets", "earliest")
    .load()
)

# %%
df_kafka.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %% [markdown]
# ## Ingestion Schema: Fetch via REST API

# %%
import requests

response = requests.get(
    "http://apicurio:8081/apis/registry/v2/groups/default/artifacts/olist.oltp.customers-value/versions/latest"
)

schema_dict = response.json()
schema_json = json.dumps(schema_dict)
schema_json
# Out:
# '{"type": "record", "name": "Value", "namespace": "olist.oltp.customers", "fields": [{"name": "customer_id", "type": "string"}, {"name": "customer_unique_id", "type": ["null", "string"], "default": null}, {"name": "customer_zip_code_prefix", "type": ["null", "string"], "default": null}, {"name": "customer_city", "type": ["null", "string"], "default": null}, {"name": "customer_state", "type": ["null", "string"], "default": null}, {"name": "created_at", "type": [{"type": "long", "connect.version": 1, "connect.default": 0, "connect.name": "io.debezium.time.MicroTimestamp"}, "null"], "default": 0}, {"name": "updated_at", "type": [{"type": "long", "connect.version": 1, "connect.default": 0, "connect.name": "io.debezium.time.MicroTimestamp"}, "null"], "default": 0}, {"name": "__op", "type": ["null", "string"], "default": null}, {"name": "__ts_ms", "type": ["null", "long"], "default": null}], "connect.name": "olist.oltp.customers.Value"}'

# %% [markdown]
# ## Deserialize/Parse Avro

# %%
from pyspark.sql.avro.functions import from_avro

df_parsed = (
    df_kafka
        .select(
            from_avro("value", schema_json).alias("data"),
            F.col("offset"),
            F.col("partition"),
            F.col("timestamp").alias("kafka_ts")
        )
        .select("data.*", "offset", "partition", "kafka_ts")
)

# %%
df_parsed.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- __op: string (nullable = true)
#  |-- __ts_ms: long (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- kafka_ts: timestamp (nullable = true)

# %% [markdown]
# ## Write into Bronze Table

# %%
# https://iceberg.apache.org/docs/latest/spark-structured-streaming/
# write > writeStream
# add checkpoint s3a://olist-ecommerce/checkpoints/bronze/customers/
# mode > outputMode
# saveAsTable > toTable

(
    df_parsed.write
    .format("iceberg")
    .mode("append")
    .saveAsTable("polaris.bronze.customers")
)
# Out:
# [09:46:18] [Thread-3] INFO  org.apache.iceberg.rest.auth.AuthManagers - Loading AuthManager implementation: org.apache.iceberg.rest.auth.OAuth2Manager
# [09:46:20] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [09:46:21] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties set at catalog level through catalog properties: {}
# [09:46:21] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties enforced at catalog level through catalog properties: {}
# [09:46:23] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [09:46:31] [Thread-3] INFO  org.apache.iceberg.spark.source.SparkWrite - Committing append with 3 new data files to table polaris.bronze.customers
# [09:46:31] [Thread-3] INFO  org.apache.iceberg.SnapshotProducer - Committed snapshot 8835816647226224864 (MergeAppend)
# ...

# %%
# %%sql
# DROP TABLE IF EXISTS polaris.bronze.customers;
# Out:
# [09:46:35] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO

# %% [markdown]
# ## Define Ingestion Configuration

# %%
INGESTION_CONFIG = [
    "customers",
    "order_items",
    "order_payments",
    "order_reviews",
    "orders",
    "products",
    "sellers"
]

# %%
for item in INGESTION_CONFIG:
    print(f"Ingesting topic olist.oltp.{item} → polaris.bronze.{item}")

    df_kafka = (
        spark.readStream
        .format("kafka")
        .option("kafka.bootstrap.servers", "kafka:9092")
        .option("subscribe", f"olist.oltp.{item}")
        .option("startingOffsets", "earliest")
        .load()
    )

    response = requests.get(
        f"http://apicurio:8081/apis/registry/v2/groups/default/artifacts/olist.oltp.{item}-value/versions/latest"
    )

    schema_dict = response.json()
    schema_json = json.dumps(schema_dict)

    df_parsed = (
        df_kafka
            .select(
                from_avro("value", schema_json).alias("data"),
                F.col("offset"),
                F.col("partition"),
                F.col("timestamp").alias("kafka_ts")
            )
            .select("data.*", "offset", "partition", "kafka_ts")
    )

    (
        df_parsed.writeStream
        .format("iceberg")
        .outputMode("append")
        .option("checkpointLocation", f"s3a://olist-ecommerce/checkpoints/bronze/{item}/")
        .toTable(f"polaris.bronze.{item}")
    )
# Out:
# Ingesting topic olist.oltp.customers → polaris.bronze.customers
# [09:48:48] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties set at catalog level through catalog properties: {}
# [09:48:48] [Thread-3] INFO  org.apache.iceberg.rest.RESTSessionCatalog - Table properties enforced at catalog level through catalog properties: {}
# [09:48:48] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# [09:48:48] [Thread-3] WARN  org.apache.hadoop.metrics2.impl.MetricsConfig - Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# [09:48:49] [Thread-3] WARN  org.apache.spark.sql.execution.streaming.ResolveWriteToStream - spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# Ingesting topic olist.oltp.order_items → polaris.bronze.order_items
# ...

# %% [markdown]
# ## Sanity Check Show All Tables

# %%
# %%sql
# SHOW TABLES IN bronze;
# Out:
# +---------+--------------+-----------+
# |namespace|tableName     |isTemporary|
# +---------+--------------+-----------+
# |bronze   |order_payments|false      |
# |bronze   |sellers       |false      |
# |bronze   |orders        |false      |
# |bronze   |products      |false      |
# |bronze   |order_reviews |false      |
# |bronze   |order_items   |false      |
# |bronze   |customers     |false      |
# +---------+--------------+-----------+

# %%
for item in INGESTION_CONFIG:
    df = spark.table(f"polaris.bronze.{item}").limit(5)
    df.show()
# Out:
# [09:49:18] [Thread-3] INFO  org.apache.iceberg.SnapshotScan - Scanning table polaris.bronze.customers snapshot 3889023909614118953 created at 2026-02-14T09:48:54.547+00:00 with filter true
# [09:49:18] [Thread-3] INFO  org.apache.iceberg.BaseDistributedDataScan - Planning file tasks locally for table polaris.bronze.customers
# ...

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
