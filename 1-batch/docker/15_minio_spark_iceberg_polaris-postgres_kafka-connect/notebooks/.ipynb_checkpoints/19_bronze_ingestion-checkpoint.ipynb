# %% [markdown]
# # Bronze Layer Ingestion

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName("olist-bronze-setup")
        .getOrCreate()
)

# Load the Spark SQL magic python file created earlier
from spark_sql_magic import sql  # registers the %%sql magic automatically
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# [10:14:12] [Thread-3] WARN  org.apache.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Read from Kafka Stream

# %%
df_kafka = (
    spark.readStream
    .format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "olist.oltp.customers")
    .option("startingOffsets", "earliest")
    .load()
)

# %% [markdown]
# ## Ingestion Schema: Fetch via REST API

# %%
import requests

response = requests.get(
    "http://apicurio:8081/apis/registry/v2/groups/default/artifacts/olist.oltp.customers-value/versions/latest"
)

schema_dict = response.json()
schema_json = json.dumps(schema_dict)
schema_json
# Out:
# {'type': 'record',
#  'name': 'Value',
#  'namespace': 'olist.oltp.customers',
#  'fields': [{'name': 'customer_id', 'type': 'string'},
#   {'name': 'customer_unique_id', 'type': ['null', 'string'], 'default': None},
#   {'name': 'customer_zip_code_prefix',
#    'type': ['null', 'string'],
#    'default': None},
#   {'name': 'customer_city', 'type': ['null', 'string'], 'default': None},
#   {'name': 'customer_state', 'type': ['null', 'string'], 'default': None},
#   {'name': 'created_at',
#    'type': [{'type': 'long',
#      'connect.version': 1,
#      'connect.default': 0,
#      'connect.name': 'io.debezium.time.MicroTimestamp'},
#     'null'],
#    'default': 0},
#   {'name': 'updated_at',
#    'type': [{'type': 'long',
#      'connect.version': 1,
#      'connect.default': 0,
#      'connect.name': 'io.debezium.time.MicroTimestamp'},
#     'null'],
#    'default': 0}],
#  'connect.name': 'olist.oltp.customers.Value'}

# %% [markdown]
# ## Deserialize Avro

# %%
from pyspark.sql.avro.functions import from_avro

df_parsed = (
    df_kafka
        .select(
            from_avro("value", schema_json).alias("data")
        )
        .select("data.*")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       1 from pyspark.sql.avro.functions import from_avro
#       3 df_parsed = (
#       4     df_kafka
#       5         .select(
# ----> 6             from_avro("value", schema_json).alias("data")
#       7         )
#       8         .select("data.*")
#       9 )
#
# NameError: name 'schema_json' is not defined

# %%
spark.sql("""CREATE NAMESPACE IF NOT EXISTS bronze""")
# Out:
# DataFrame[]

# %%
spark.sql("SHOW NAMESPACES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |   bronze|
# +---------+

# %%
kafka_raw_df = (
    spark.read.format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "olist.oltp.customers")
    .option("startingOffsets", "earliest")
    .load()
)

# %%
kafka_raw_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
spark.catalog.clearCache()  # clears all cached tables
spark.stop()
