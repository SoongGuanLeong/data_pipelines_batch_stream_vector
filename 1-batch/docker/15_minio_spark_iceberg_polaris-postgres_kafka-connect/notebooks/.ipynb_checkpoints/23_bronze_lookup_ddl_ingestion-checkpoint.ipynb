# %% [markdown]
# # Bronze Lookup DDL Ingestion

# %% [markdown]
# ## Import Helper Functions

# %%
from pathlib import Path

from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# from src.config import *
# from src.spark_sql_magic import sql\
# from ingestion.metadata_utils import log_ingestion_metadata
# from src.raw_utils import checksum

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["bronze_lookup_ddl_ingestion"])
        .getOrCreate()
)

# %% [markdown]
# ## DDL

# %%
for table_name, data in LOOKUP_TABLES.items():
    full_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{table_name}"
    
    spark.sql(f"""
        CREATE TABLE IF NOT EXISTS {full_table} (
            {data['schema']}
        )
        USING ICEBERG
    """)
    print(f"{full_table} created.")
# Out:
# polaris.bronze.geolocation created.
# polaris.bronze.product_category_name created.

# %% [markdown]
# ## Ingestion

# %%
for table_name, data in LOOKUP_TABLES.items():
    full_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{table_name}"
    
    df = spark.read.csv(data['file_path'], header=True)
    df.write.format("iceberg").mode("overwrite").saveAsTable(full_table)
    print(f"{table_name} ingested.")

    # This is a 'Blocking' call. It forces Spark to wait until 
    # the table is actually ready before moving to the next line.
    spark.table(full_table).collect()
    
    # metadata logging
    spark_path = full_table   # here it's table-based, not s3 object
    file_path = Path(data['file_path'])
    file_checksum = checksum(file_path)

    log_ingestion_metadata(
        spark=spark,
        table_name=f"{CATALOG}.{BRONZE_NAMESPACE}.{LOOKUP_METADATA_TABLE}",   # your metadata Iceberg table
        file_path=file_path,
        spark_path=spark_path,
        checksum=file_checksum
    )
# Out:
# geolocation ingested.
# product_category_name ingested.

# %% [markdown]
# ## Sanity Check

# %%
for table_name, data in LOOKUP_TABLES.items():
    full_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{table_name}"

    spark.sql(f" FROM {full_table} ").show()
    spark.sql(f"FROM {CATALOG}.{BRONZE_NAMESPACE}.{LOOKUP_METADATA_TABLE}")
# Out:
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |geolocation_zip_code_prefix|    geolocation_lat|    geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |                      01037| -23.54562128115268| -46.63929204800168|       sao paulo|               SP|
# |                      01046|-23.546081127035535| -46.64482029837157|       sao paulo|               SP|
# |                      01046| -23.54612896641469| -46.64295148361138|       sao paulo|               SP|
# |                      01041|  -23.5443921648681| -46.63949930627844|       sao paulo|               SP|
# |                      01035|-23.541577961711493| -46.64160722329613|       sao paulo|               SP|
# |                      01012|-23.547762303364266| -46.63536053788448|       são paulo|               SP|
# ...
