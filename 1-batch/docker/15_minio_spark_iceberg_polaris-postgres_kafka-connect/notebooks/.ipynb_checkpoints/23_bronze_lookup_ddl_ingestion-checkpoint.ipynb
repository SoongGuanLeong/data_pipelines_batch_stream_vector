# %% [markdown]
# # Bronze Lookup DDL Ingestion

# %% [markdown]
# ## Import Helper Functions

# %%
from pathlib import Path

from src import *

# while it is allowed to use the import above, it is advised to list out what we have imported
# from src.config_loader import load_config
# from src.spark_sql_magic import sql
# from src.metadata_utils import log_ingestion_metadata
# from src.file_utils import checksum
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# ## Load Configs

# %%
cfg = load_config()

JOB_NAMES = cfg["spark_jobs"]["jobs"]
CATALOG = cfg["general"]["catalog"]
BRONZE_NAMESPACE = cfg["general"]["namespaces"]["bronze"]
LOOKUP_TABLES = cfg["raw"]["lookup_tables"]
LOOKUP_METADATA_TABLE = cfg["raw"]["lookup_metadata_table"]
ALLOWED_TYPES = set(cfg["raw"]["allowed_types"])

# %% [markdown]
# ## Import Libraries and Start Session

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import Window as W
import pyspark
import datetime
import json

spark = (
    SparkSession.builder
        .appName(JOB_NAMES["bronze_lookup_ddl_ingestion"])
        .getOrCreate()
)

# %% [markdown]
# ## DDL

# %%
for table_name, data in LOOKUP_TABLES.items():
    full_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{table_name}"
    
    spark.sql(f"""
        CREATE TABLE IF NOT EXISTS {full_table} (
            {data['schema']}
        )
        USING ICEBERG
    """)
    print(f"{full_table} created.")
# Out:
# polaris.bronze.geolocation created.
# polaris.bronze.product_category_name created.

# %% [markdown]
# ## Ingestion

# %%
lookup_metadata_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{LOOKUP_METADATA_TABLE}"

ddl_metadata_table(spark, lookup_metadata_table)

for table_name, data in LOOKUP_TABLES.items():
    full_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{table_name}"
    file_path = Path(data["file_path"])

    # ---- Idempotency Check ----
    file_checksum = checksum(file_path)
    if already_ingested(spark, lookup_metadata_table, file_checksum):
        print(f"⚠️ {table_name} already ingested. Skipping.")
        continue
    
    df = spark.read.csv(data['file_path'], header=True)
    df.write.format("iceberg").mode("overwrite").saveAsTable(full_table)
    print(f"{table_name} ingested.")

    # Force materialization (blocking call)
    spark.table(full_table).collect()
    
    # metadata logging 
    log_ingestion_metadata(
        spark=spark,
        table_name=lookup_metadata_table,   # your metadata Iceberg table
        file_path=file_path,
        spark_path=full_table,             # here it's table-based, not s3 object
        checksum=file_checksum,
        allowed_types=ALLOWED_TYPES
    )
# Out:
# polaris.bronze.lookup_ingestion_metadata created.
# geolocation ingested.
# polaris.bronze.lookup_ingestion_metadata ingested
# product_category_name ingested.
# polaris.bronze.lookup_ingestion_metadata ingested

# %% [markdown]
# ## Sanity Check

# %%
for table_name, data in LOOKUP_TABLES.items():
    full_table = f"{CATALOG}.{BRONZE_NAMESPACE}.{table_name}"

    spark.sql(f" FROM {full_table} ").show(5)
    spark.sql(f"SELECT COUNT(1) FROM {full_table} ").show()
    spark.sql(f"FROM {CATALOG}.{BRONZE_NAMESPACE}.{LOOKUP_METADATA_TABLE}").show()
# Out:
# +---------------------------+-------------------+------------------+----------------+-----------------+
# |geolocation_zip_code_prefix|    geolocation_lat|   geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+-------------------+------------------+----------------+-----------------+
# |                      01037| -23.54562128115268|-46.63929204800168|       sao paulo|               SP|
# |                      01046|-23.546081127035535|-46.64482029837157|       sao paulo|               SP|
# |                      01046| -23.54612896641469|-46.64295148361138|       sao paulo|               SP|
# |                      01041|  -23.5443921648681|-46.63949930627844|       sao paulo|               SP|
# |                      01035|-23.541577961711493|-46.64160722329613|       sao paulo|               SP|
# +---------------------------+-------------------+------------------+----------------+-----------------+
# only showing top 5 rows
# +--------+
# ...
