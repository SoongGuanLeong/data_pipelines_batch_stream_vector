# %% [markdown]
# # Bronze Layer Ingestion

# %% [markdown]
# ## 1 - Start SparkSession

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
        .appName("olist-bronze-setup")
        .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# [03:20:13] [Thread-3] WARN  org.apache.hadoop.util.NativeCodeLoader - Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## 2 - Create Namespace

# %%
spark.sql("SHOW CATALOGS").show()
# Out:
# +-------------+
# |      catalog|
# +-------------+
# |spark_catalog|
# +-------------+

# %%
spark.sql("USE polaris")
# Out:
# [03:20:26] [Thread-3] INFO  org.apache.iceberg.rest.auth.AuthManagers - Loading AuthManager implementation: org.apache.iceberg.rest.auth.OAuth2Manager
# [03:20:27] [Thread-3] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# DataFrame[]

# %%
spark.sql("""CREATE NAMESPACE IF NOT EXISTS bronze""")
# Out:
# DataFrame[]

# %%
spark.sql("SHOW NAMESPACES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |   bronze|
# +---------+

# %%
kafka_raw_df = (
    spark.read.format("kafka")
    .option("kafka.bootstrap.servers", "kafka:9092")
    .option("subscribe", "olist.oltp.customers")
    .option("startingOffsets", "earliest")
    .load()
)

# %%
kafka_raw_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
